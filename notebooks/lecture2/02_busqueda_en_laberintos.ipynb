# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
cd "/content/drive/MyDrive/Courses/SI3003 - Inteligencia Artificial/Clase02"
# Out:
# /content/drive/MyDrive/Courses/SI3003 - Inteligencia Artificial/Clase02

# %% [markdown]
# # Búsqueda en laberintos: la misma arquitectura, otro problema
#
# **Curso:** SI3003 — Inteligencia Artificial
#
# 1. **Cómo se representa el problema** (`Maze` en vez de un diccionario `graph`).
# 2. **Cómo se generan los vecinos de un estado** (`maze.neighbors(state)` en vez de `graph[state]`).
#
# Si ya resolviste el notebook de grafos, cada célula de código de la Parte 1 debería resultarte familiar: es el mismo algoritmo, aplicado a un problema donde los estados son coordenadas `(fila, columna)` en vez de letras.

# %% [markdown]
# ## 1. Problema de búsqueda
#
# - **Estado inicial:** la celda marcada con `A`.
# - **Estado objetivo:** la celda marcada con `B`.
# - **Estados:** todas las celdas transitables del laberinto.
# - Los muros (`#`) no son estados válidos.
#
# A diferencia del grafo `A → H` del notebook anterior, aquí **no tenemos la lista de vecinos escrita a mano**: hay que calcularla a partir de la posición `(fila, columna)` y del layout del laberinto.

# %%
from __future__ import annotations

from pathlib import Path
from itertools import count
import heapq

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %% [markdown]
# ## 2. Representación del problema
#
# En el grafo, cada vecino era una tupla `(estado_vecino, costo_de_la_arista)`:
#
# ```python
# graph = {
#     "A": [("B", 2), ("C", 1)],
#     ...
# }
# ```
#
# En el laberinto **no escribimos esa lista a mano** — la calculamos con un método `neighbors(state)` que:
#
# 1. Genera las cuatro celdas adyacentes (arriba, abajo, izquierda, derecha).
# 2. Descarta las que caen fuera de la cuadrícula o son muro.
# 3. Devuelve **exactamente el mismo formato** que usaba el grafo: una lista de tuplas `(estado_vecino, costo)`, con costo `1` porque cada paso ortogonal cuesta lo mismo.
#
# ```python
# for child_state, edge_cost in graph[node.state]:
# ```
#
# se convierte simplemente en
#
# ```python
# for child_state, edge_cost in maze.neighbors(node.state):
# ```
#
# Nada más cambia dentro del algoritmo.

# %%
class Maze:
    def __init__(self, filename: str | Path):
        self.filename = Path(filename)
        contents = self.filename.read_text(encoding="utf-8")

        if contents.count("A") != 1:
            raise ValueError("El laberinto debe tener exactamente un punto inicial A.")
        if contents.count("B") != 1:
            raise ValueError("El laberinto debe tener exactamente una meta B.")

        lines = contents.splitlines()
        self.height = len(lines)
        self.width = max(len(line) for line in lines)
        self.walls = np.zeros((self.height, self.width), dtype=bool)

        for row in range(self.height):
            for col in range(self.width):
                symbol = lines[row][col] if col < len(lines[row]) else "#"

                if symbol == "A":
                    self.start = (row, col)
                elif symbol == "B":
                    self.goal = (row, col)
                elif symbol != " ":
                    self.walls[row, col] = True

    def neighbors(self, state: tuple[int, int]):
        """Devuelve vecinos en el MISMO formato que graph[node.state]:
        una lista de tuplas (estado_vecino, costo_de_la_arista)."""
        row, col = state
        candidates = [
            (row - 1, col),
            (row + 1, col),
            (row, col - 1),
            (row, col + 1),
        ]

        valid = []
        for r, c in candidates:
            if (
                0 <= r < self.height
                and 0 <= c < self.width
                and not self.walls[r, c]
            ):
                valid.append(((r, c), 1))
        return valid

    def show(self, path=None, explored=None, title="Laberinto", figsize=(6, 6)):
        # 0: libre, 1: muro, 2: explorado, 3: camino, 4: inicio, 5: meta
        grid = np.zeros((self.height, self.width), dtype=int)
        grid[self.walls] = 1

        if explored:
            for r, c in explored:
                if grid[r, c] == 0:
                    grid[r, c] = 2

        if path:
            for r, c in path:
                if grid[r, c] in (0, 2):
                    grid[r, c] = 3

        grid[self.start] = 4
        grid[self.goal] = 5

        colors = ["white", "#222222", "#a9d6e5", "#ffb703", "#2a9d8f", "#e63946"]
        cmap = ListedColormap(colors)

        plt.figure(figsize=figsize)
        plt.imshow(grid, cmap=cmap, vmin=0, vmax=5)
        plt.xticks([])
        plt.yticks([])
        plt.title(title)
        plt.show()

# %%
maze1 = Maze("mazes/mazes/maze1.txt")

print("Dimensiones:", maze1.height, "x", maze1.width)
print("Estado inicial:", maze1.start)
print("Estado objetivo:", maze1.goal)
print("Vecinos del estado inicial:", maze1.neighbors(maze1.start))

maze1.show(title="Maze 1: problema inicial")
# Out:
# Dimensiones: 17 x 17
# Estado inicial: (1, 1)
# Estado objetivo: (15, 15)
# Vecinos del estado inicial: [((2, 1), 1), ((1, 2), 1)]

# %% [markdown]
# ### Pregunta para discutir
#
# ¿La posición del agente es suficiente para describir completamente un estado en este problema?
#
# En este laberinto, sí: el comportamiento futuro depende únicamente de la celda actual, porque los muros no cambian y el agente no necesita recordar acciones anteriores. Es exactamente la misma situación que en el grafo `A–H`: el estado era la letra, no la secuencia de letras visitadas.

# %% [markdown]
# ## 3. Estructuras comunes
#
# `Node` y `reconstruct_path` son **copiados sin ningún cambio** desde el notebook de grafos. Un nodo de búsqueda guarda:
#
# - `state`: estado actual (antes era una letra, ahora es una tupla `(fila, columna)`).
# - `parent`: nodo desde el cual se llegó.
# - `cost`: costo acumulado \(g(n)\).

# %%
class Node:
    def __init__(self, state, parent=None, cost=0):
        self.state = state
        self.parent = parent
        self.cost = cost

    def __repr__(self):
        return f"{self.state}(g={self.cost})"

# %%
def reconstruct_path(node):
    path = []

    while node is not None:
        path.append(node.state)
        node = node.parent

    return list(reversed(path))

# %% [markdown]
# ## 4. DFS
#
# DFS utiliza una **pila LIFO**. Los costos existen en el laberinto (cada paso cuesta 1), pero DFS no los utiliza para decidir qué nodo expandir.
#
# `StackFrontier` es exactamente la misma clase del notebook de grafos.

# %%
class StackFrontier:
    def __init__(self):
        self.frontier = []

    def add(self, node):
        self.frontier.append(node)

    def contains_state(self, state):
        return any(node.state == state for node in self.frontier)

    def empty(self):
        return len(self.frontier) == 0

    def remove(self):
        if self.empty():
            raise Exception("La frontier está vacía.")

        return self.frontier.pop()

    def states(self):
        return [node.state for node in self.frontier]

# %%
def depth_first_search(maze, start, goal, verbose=False):
    frontier = StackFrontier()
    frontier.add(Node(start))

    explored = set()
    expansion_order = []

    while not frontier.empty():
        node = frontier.remove()
        expansion_order.append(node.state)

        if verbose:
            print(f"Expandiendo: {node.state}")

        if node.state == goal:
            return {
                "path": reconstruct_path(node),
                "expansion_order": expansion_order,
                "cost": node.cost
            }

        explored.add(node.state)

        for child_state, edge_cost in maze.neighbors(node.state):
            if (
                child_state not in explored
                and not frontier.contains_state(child_state)
            ):
                child = Node(
                    state=child_state,
                    parent=node,
                    cost=node.cost + edge_cost
                )
                frontier.add(child)

    return None

# %% [markdown]
# Compara esta función con `depth_first_search` del notebook de grafos: son **idénticas**, salvo por la línea
#
# ```python
# for child_state, edge_cost in maze.neighbors(node.state):
# ```
#
# que en el grafo era
#
# ```python
# for child_state, edge_cost in graph[node.state]:
# ```

# %%
start, goal = maze1.start, maze1.goal

dfs_result = depth_first_search(maze1, start, goal)

print("Estados explorados:", len(dfs_result["expansion_order"]))
print("Longitud del camino:", len(dfs_result["path"]) - 1)
print("Costo del camino:", dfs_result["cost"])

maze1.show(
    path=dfs_result["path"],
    explored=set(dfs_result["expansion_order"]),
    title="DFS: estados explorados y solución"
)
# Out:
# Estados explorados: 69
# Longitud del camino: 64
# Costo del camino: 64

# %% [markdown]
# ### Observación
#
# DFS sigue una rama tan profundamente como sea posible antes de retroceder. En este laberinto encuentra una solución, pero **claramente no la más corta**: compárala con el resultado de BFS en la siguiente sección.

# %% [markdown]
# ## 5. BFS — actividad
#
# BFS utiliza una **cola FIFO**.
#
# ### Tareas
#
# 1. Complete el método `remove` de `QueueFrontier`.
# 2. Complete `breadth_first_search`.
# 3. Verifique el orden de expansión y el camino encontrado.
# 4. Compare el resultado con DFS: ¿cuál encuentra el camino más corto?

# %%
class QueueFrontier(StackFrontier):
    def remove(self):
        if self.empty():
            raise Exception("La frontier está vacía.")

        return self.frontier.pop(0)

# %%
def breadth_first_search(maze, start, goal, verbose=True):
    frontier = QueueFrontier()
    frontier.add(Node(start))

    explored = set()
    expansion_order = []
    while not frontier.empty():
        node = frontier.remove()
        expansion_order.append(node.state)

        if verbose:
            print(f"Expandiendo: {node.state}")
            
        if node.state == goal:
            return {
                "path": reconstruct_path(node),
                "expansion_order": expansion_order,
                "cost": node.cost
            }

        explored.add(node.state)

        for child_state, edge_cost in maze.neighbors(node.state):
            if (
                child_state not in explored
                and not frontier.contains_state(child_state)
            ):
                child = Node(
                    state=child_state,
                    parent=node,
                    cost=node.cost + edge_cost
                )
                frontier.add(child)

        if verbose:
            print(f"Frontier después de expandir: {frontier.states()}")
            print("-" * 45)

    return None

# %%
start, goal = maze1.start, maze1.goal

bfs_result = breadth_first_search(maze1, start, goal)

print("Estados explorados:", len(bfs_result["expansion_order"]))
print("Longitud del camino:", len(bfs_result["path"]) - 1)
print("Costo del camino:", bfs_result["cost"])

maze1.show(
    path=bfs_result["path"],
    explored=set(bfs_result["expansion_order"]),
    title="BFS: estados explorados y solución"
)
# Out:
# Expandiendo: (1, 1)
# Frontier después de expandir: [(2, 1), (1, 2)]
# ---------------------------------------------
# Expandiendo: (2, 1)
# Frontier después de expandir: [(1, 2), (3, 1)]
# ---------------------------------------------
# Expandiendo: (1, 2)
# Frontier después de expandir: [(3, 1), (1, 3)]
# ---------------------------------------------
# Expandiendo: (3, 1)
# Frontier después de expandir: [(1, 3), (4, 1), (3, 2)]
# ---------------------------------------------
# Expandiendo: (1, 3)
# Frontier después de expandir: [(4, 1), (3, 2), (1, 4)]
# ---------------------------------------------
# Expandiendo: (4, 1)
# Frontier después de expandir: [(3, 2), (1, 4), (5, 1)]
# ---------------------------------------------
# Expandiendo: (3, 2)
# Frontier después de expandir: [(1, 4), (5, 1), (3, 3)]
# ---------------------------------------------
# Expandiendo: (1, 4)
# Frontier después de expandir: [(5, 1), (3, 3), (1, 5)]
# ---------------------------------------------
# Expandiendo: (5, 1)
# Frontier después de expandir: [(3, 3), (1, 5), (6, 1), (5, 2)]
# ---------------------------------------------
# Expandiendo: (3, 3)
# Frontier después de expandir: [(1, 5), (6, 1), (5, 2), (3, 4)]
# ---------------------------------------------
# Expandiendo: (1, 5)
# Frontier después de expandir: [(6, 1), (5, 2), (3, 4), (2, 5)]
# ---------------------------------------------
# Expandiendo: (6, 1)
# Frontier después de expandir: [(5, 2), (3, 4), (2, 5), (7, 1)]
# ---------------------------------------------
# Expandiendo: (5, 2)
# Frontier después de expandir: [(3, 4), (2, 5), (7, 1), (5, 3)]
# ---------------------------------------------
# Expandiendo: (3, 4)
# Frontier después de expandir: [(2, 5), (7, 1), (5, 3), (3, 5)]
# ---------------------------------------------
# Expandiendo: (2, 5)
# Frontier después de expandir: [(7, 1), (5, 3), (3, 5)]
# ---------------------------------------------
# Expandiendo: (7, 1)
# Frontier después de expandir: [(5, 3), (3, 5), (7, 2)]
# ---------------------------------------------
# Expandiendo: (5, 3)
# Frontier después de expandir: [(3, 5), (7, 2), (5, 4)]
# ---------------------------------------------
# Expandiendo: (3, 5)
# Frontier después de expandir: [(7, 2), (5, 4)]
# ---------------------------------------------
# Expandiendo: (7, 2)
# Frontier después de expandir: [(5, 4), (7, 3)]
# ---------------------------------------------
# Expandiendo: (5, 4)
# Frontier después de expandir: [(7, 3), (5, 5)]
# ---------------------------------------------
# Expandiendo: (7, 3)
# Frontier después de expandir: [(5, 5), (8, 3), (7, 4)]
# ---------------------------------------------
# Expandiendo: (5, 5)
# Frontier después de expandir: [(8, 3), (7, 4), (6, 5), (5, 6)]
# ---------------------------------------------
# Expandiendo: (8, 3)
# Frontier después de expandir: [(7, 4), (6, 5), (5, 6), (9, 3)]
# ---------------------------------------------
# Expandiendo: (7, 4)
# Frontier después de expandir: [(6, 5), (5, 6), (9, 3), (7, 5)]
# ---------------------------------------------
# Expandiendo: (6, 5)
# Frontier después de expandir: [(5, 6), (9, 3), (7, 5)]
# ---------------------------------------------
# Expandiendo: (5, 6)
# Frontier después de expandir: [(9, 3), (7, 5), (5, 7)]
# ---------------------------------------------
# Expandiendo: (9, 3)
# Frontier después de expandir: [(7, 5), (5, 7), (10, 3)]
# ---------------------------------------------
# Expandiendo: (7, 5)
# Frontier después de expandir: [(5, 7), (10, 3), (8, 5)]
# ---------------------------------------------
# Expandiendo: (5, 7)
# Frontier después de expandir: [(10, 3), (8, 5), (5, 8)]
# ---------------------------------------------
# Expandiendo: (10, 3)
# Frontier después de expandir: [(8, 5), (5, 8), (11, 3)]
# ---------------------------------------------
# Expandiendo: (8, 5)
# Frontier después de expandir: [(5, 8), (11, 3), (9, 5)]
# ---------------------------------------------
# Expandiendo: (5, 8)
# Frontier después de expandir: [(11, 3), (9, 5), (5, 9)]
# ---------------------------------------------
# Expandiendo: (11, 3)
# Frontier después de expandir: [(9, 5), (5, 9), (12, 3)]
# ---------------------------------------------
# Expandiendo: (9, 5)
# Frontier después de expandir: [(5, 9), (12, 3), (10, 5)]
# ---------------------------------------------
# Expandiendo: (5, 9)
# Frontier después de expandir: [(12, 3), (10, 5), (4, 9)]
# ---------------------------------------------
# Expandiendo: (12, 3)
# Frontier después de expandir: [(10, 5), (4, 9), (13, 3)]
# ---------------------------------------------
# Expandiendo: (10, 5)
# Frontier después de expandir: [(4, 9), (13, 3), (11, 5)]
# ---------------------------------------------
# Expandiendo: (4, 9)
# Frontier después de expandir: [(13, 3), (11, 5), (3, 9)]
# ---------------------------------------------
# Expandiendo: (13, 3)
# Frontier después de expandir: [(11, 5), (3, 9), (14, 3), (13, 2), (13, 4)]
# ---------------------------------------------
# Expandiendo: (11, 5)
# Frontier después de expandir: [(3, 9), (14, 3), (13, 2), (13, 4), (12, 5)]
# ---------------------------------------------
# Expandiendo: (3, 9)
# Frontier después de expandir: [(14, 3), (13, 2), (13, 4), (12, 5), (3, 10)]
# ---------------------------------------------
# Expandiendo: (14, 3)
# Frontier después de expandir: [(13, 2), (13, 4), (12, 5), (3, 10), (15, 3)]
# ---------------------------------------------
# Expandiendo: (13, 2)
# Frontier después de expandir: [(13, 4), (12, 5), (3, 10), (15, 3), (13, 1)]
# ---------------------------------------------
# Expandiendo: (13, 4)
# Frontier después de expandir: [(12, 5), (3, 10), (15, 3), (13, 1), (13, 5)]
# ---------------------------------------------
# Expandiendo: (12, 5)
# Frontier después de expandir: [(3, 10), (15, 3), (13, 1), (13, 5)]
# ---------------------------------------------
# Expandiendo: (3, 10)
# Frontier después de expandir: [(15, 3), (13, 1), (13, 5), (3, 11)]
# ---------------------------------------------
# Expandiendo: (15, 3)
# Frontier después de expandir: [(13, 1), (13, 5), (3, 11), (15, 2), (15, 4)]
# ---------------------------------------------
# Expandiendo: (13, 1)
# Frontier después de expandir: [(13, 5), (3, 11), (15, 2), (15, 4), (12, 1), (14, 1)]
# ---------------------------------------------
# Expandiendo: (13, 5)
# Frontier después de expandir: [(3, 11), (15, 2), (15, 4), (12, 1), (14, 1), (14, 5), (13, 6)]
# ---------------------------------------------
# Expandiendo: (3, 11)
# Frontier después de expandir: [(15, 2), (15, 4), (12, 1), (14, 1), (14, 5), (13, 6), (4, 11)]
# ---------------------------------------------
# Expandiendo: (15, 2)
# Frontier después de expandir: [(15, 4), (12, 1), (14, 1), (14, 5), (13, 6), (4, 11), (15, 1)]
# ---------------------------------------------
# Expandiendo: (15, 4)
# Frontier después de expandir: [(12, 1), (14, 1), (14, 5), (13, 6), (4, 11), (15, 1), (15, 5)]
# ---------------------------------------------
# Expandiendo: (12, 1)
# Frontier después de expandir: [(14, 1), (14, 5), (13, 6), (4, 11), (15, 1), (15, 5), (11, 1)]
# ---------------------------------------------
# Expandiendo: (14, 1)
# Frontier después de expandir: [(14, 5), (13, 6), (4, 11), (15, 1), (15, 5), (11, 1)]
# ---------------------------------------------
# Expandiendo: (14, 5)
# Frontier después de expandir: [(13, 6), (4, 11), (15, 1), (15, 5), (11, 1)]
# ---------------------------------------------
# Expandiendo: (13, 6)
# Frontier después de expandir: [(4, 11), (15, 1), (15, 5), (11, 1), (13, 7)]
# ---------------------------------------------
# Expandiendo: (4, 11)
# Frontier después de expandir: [(15, 1), (15, 5), (11, 1), (13, 7), (5, 11)]
# ---------------------------------------------
# Expandiendo: (15, 1)
# Frontier después de expandir: [(15, 5), (11, 1), (13, 7), (5, 11)]
# ---------------------------------------------
# Expandiendo: (15, 5)
# Frontier después de expandir: [(11, 1), (13, 7), (5, 11)]
# ---------------------------------------------
# Expandiendo: (11, 1)
# Frontier después de expandir: [(13, 7), (5, 11), (10, 1)]
# ---------------------------------------------
# Expandiendo: (13, 7)
# Frontier después de expandir: [(5, 11), (10, 1), (12, 7), (13, 8)]
# ---------------------------------------------
# Expandiendo: (5, 11)
# Frontier después de expandir: [(10, 1), (12, 7), (13, 8), (6, 11)]
# ---------------------------------------------
# Expandiendo: (10, 1)
# Frontier después de expandir: [(12, 7), (13, 8), (6, 11), (9, 1)]
# ---------------------------------------------
# Expandiendo: (12, 7)
# Frontier después de expandir: [(13, 8), (6, 11), (9, 1), (11, 7)]
# ---------------------------------------------
# Expandiendo: (13, 8)
# Frontier después de expandir: [(6, 11), (9, 1), (11, 7), (13, 9)]
# ---------------------------------------------
# Expandiendo: (6, 11)
# Frontier después de expandir: [(9, 1), (11, 7), (13, 9), (7, 11)]
# ---------------------------------------------
# Expandiendo: (9, 1)
# Frontier después de expandir: [(11, 7), (13, 9), (7, 11)]
# ---------------------------------------------
# Expandiendo: (11, 7)
# Frontier después de expandir: [(13, 9), (7, 11), (10, 7)]
# ---------------------------------------------
# Expandiendo: (13, 9)
# Frontier después de expandir: [(7, 11), (10, 7), (14, 9)]
# ---------------------------------------------
# Expandiendo: (7, 11)
# Frontier después de expandir: [(10, 7), (14, 9), (7, 12)]
# ---------------------------------------------
# Expandiendo: (10, 7)
# Frontier después de expandir: [(14, 9), (7, 12), (9, 7)]
# ---------------------------------------------
# Expandiendo: (14, 9)
# Frontier después de expandir: [(7, 12), (9, 7), (15, 9)]
# ---------------------------------------------
# Expandiendo: (7, 12)
# Frontier después de expandir: [(9, 7), (15, 9), (7, 13)]
# ---------------------------------------------
# Expandiendo: (9, 7)
# Frontier después de expandir: [(15, 9), (7, 13), (8, 7), (9, 8)]
# ---------------------------------------------
# Expandiendo: (15, 9)
# Frontier después de expandir: [(7, 13), (8, 7), (9, 8), (15, 8), (15, 10)]
# ---------------------------------------------
# Expandiendo: (7, 13)
# Frontier después de expandir: [(8, 7), (9, 8), (15, 8), (15, 10), (8, 13)]
# ---------------------------------------------
# Expandiendo: (8, 7)
# Frontier después de expandir: [(9, 8), (15, 8), (15, 10), (8, 13), (7, 7)]
# ---------------------------------------------
# Expandiendo: (9, 8)
# Frontier después de expandir: [(15, 8), (15, 10), (8, 13), (7, 7), (9, 9)]
# ---------------------------------------------
# Expandiendo: (15, 8)
# Frontier después de expandir: [(15, 10), (8, 13), (7, 7), (9, 9), (15, 7)]
# ---------------------------------------------
# Expandiendo: (15, 10)
# Frontier después de expandir: [(8, 13), (7, 7), (9, 9), (15, 7), (15, 11)]
# ---------------------------------------------
# Expandiendo: (8, 13)
# Frontier después de expandir: [(7, 7), (9, 9), (15, 7), (15, 11), (9, 13)]
# ---------------------------------------------
# Expandiendo: (7, 7)
# Frontier después de expandir: [(9, 9), (15, 7), (15, 11), (9, 13), (7, 8)]
# ---------------------------------------------
# Expandiendo: (9, 9)
# Frontier después de expandir: [(15, 7), (15, 11), (9, 13), (7, 8), (8, 9), (10, 9), (9, 10)]
# ---------------------------------------------
# Expandiendo: (15, 7)
# Frontier después de expandir: [(15, 11), (9, 13), (7, 8), (8, 9), (10, 9), (9, 10)]
# ---------------------------------------------
# Expandiendo: (15, 11)
# Frontier después de expandir: [(9, 13), (7, 8), (8, 9), (10, 9), (9, 10), (15, 12)]
# ---------------------------------------------
# Expandiendo: (9, 13)
# Frontier después de expandir: [(7, 8), (8, 9), (10, 9), (9, 10), (15, 12), (10, 13), (9, 14)]
# ---------------------------------------------
# Expandiendo: (7, 8)
# Frontier después de expandir: [(8, 9), (10, 9), (9, 10), (15, 12), (10, 13), (9, 14), (7, 9)]
# ---------------------------------------------
# Expandiendo: (8, 9)
# Frontier después de expandir: [(10, 9), (9, 10), (15, 12), (10, 13), (9, 14), (7, 9)]
# ---------------------------------------------
# Expandiendo: (10, 9)
# Frontier después de expandir: [(9, 10), (15, 12), (10, 13), (9, 14), (7, 9), (11, 9)]
# ---------------------------------------------
# Expandiendo: (9, 10)
# Frontier después de expandir: [(15, 12), (10, 13), (9, 14), (7, 9), (11, 9), (9, 11)]
# ---------------------------------------------
# Expandiendo: (15, 12)
# Frontier después de expandir: [(10, 13), (9, 14), (7, 9), (11, 9), (9, 11), (15, 13)]
# ---------------------------------------------
# Expandiendo: (10, 13)
# Frontier después de expandir: [(9, 14), (7, 9), (11, 9), (9, 11), (15, 13), (11, 13)]
# ---------------------------------------------
# Expandiendo: (9, 14)
# Frontier después de expandir: [(7, 9), (11, 9), (9, 11), (15, 13), (11, 13), (9, 15)]
# ---------------------------------------------
# Expandiendo: (7, 9)
# Frontier después de expandir: [(11, 9), (9, 11), (15, 13), (11, 13), (9, 15)]
# ---------------------------------------------
# Expandiendo: (11, 9)
# Frontier después de expandir: [(9, 11), (15, 13), (11, 13), (9, 15), (11, 10)]
# ---------------------------------------------
# Expandiendo: (9, 11)
# Frontier después de expandir: [(15, 13), (11, 13), (9, 15), (11, 10)]
# ---------------------------------------------
# Expandiendo: (15, 13)
# Frontier después de expandir: [(11, 13), (9, 15), (11, 10), (15, 14)]
# ---------------------------------------------
# Expandiendo: (11, 13)
# Frontier después de expandir: [(9, 15), (11, 10), (15, 14), (11, 14)]
# ---------------------------------------------
# Expandiendo: (9, 15)
# Frontier después de expandir: [(11, 10), (15, 14), (11, 14), (8, 15), (10, 15)]
# ---------------------------------------------
# Expandiendo: (11, 10)
# Frontier después de expandir: [(15, 14), (11, 14), (8, 15), (10, 15), (11, 11)]
# ---------------------------------------------
# Expandiendo: (15, 14)
# Frontier después de expandir: [(11, 14), (8, 15), (10, 15), (11, 11), (15, 15)]
# ---------------------------------------------
# Expandiendo: (11, 14)
# Frontier después de expandir: [(8, 15), (10, 15), (11, 11), (15, 15), (11, 15)]
# ---------------------------------------------
# Expandiendo: (8, 15)
# Frontier después de expandir: [(10, 15), (11, 11), (15, 15), (11, 15), (7, 15)]
# ---------------------------------------------
# Expandiendo: (10, 15)
# Frontier después de expandir: [(11, 11), (15, 15), (11, 15), (7, 15)]
# ---------------------------------------------
# Expandiendo: (11, 11)
# Frontier después de expandir: [(15, 15), (11, 15), (7, 15), (12, 11)]
# ---------------------------------------------
# Expandiendo: (15, 15)
# Estados explorados: 106
# Longitud del camino: 28
# Costo del camino: 28

# %%
# Pruebas públicas para BFS
assert bfs_result["path"][0] == start
assert bfs_result["path"][-1] == goal
assert bfs_result["cost"] == 28
assert len(bfs_result["path"]) == 29

print("✓ BFS pasó las pruebas.")
# Out:
# ✓ BFS pasó las pruebas.

# %% [markdown]
# ### DFS frente a BFS
#
# Cuando todas las acciones cuestan lo mismo:
#
# - BFS expande los nodos por niveles y su primera solución es de profundidad mínima.
# - DFS normalmente requiere menos memoria, pero su solución puede ser mucho más larga (en `maze1`, DFS encontró un camino de costo 64 frente al óptimo de 28).

# %% [markdown]
# ## 6. UCS — implementación entregada
#
# UCS utiliza una **cola de prioridad** y siempre expande el nodo con menor costo acumulado:
#
# $$
# g(n)
# $$
#
# Si aparece un camino más barato hacia un estado que ya estaba en la frontier, se conserva el de menor costo. `PriorityFrontier` es la misma clase del notebook de grafos.

# %%
class PriorityFrontier:
    def __init__(self):
        self.heap = []
        self.counter = count()

    def add(self, node, priority):
        # El contador permite desempatar respetando el orden de inserción.
        heapq.heappush(
            self.heap,
            (priority, next(self.counter), node)
        )

    def empty(self):
        return len(self.heap) == 0

    def remove(self):
        if self.empty():
            raise Exception("La frontier está vacía.")

        priority, _, node = heapq.heappop(self.heap)
        return node, priority

# %%
def uniform_cost_search(maze, start, goal, verbose=False):
    frontier = PriorityFrontier()
    frontier.add(Node(start, cost=0), priority=0)

    # Mejor costo conocido para cada estado.
    best_cost = {start: 0}

    explored = set()
    expansion_order = []

    while not frontier.empty():
        node, priority = frontier.remove()

        # Ignorar entradas antiguas de la cola de prioridad.
        if node.cost != best_cost.get(node.state):
            continue

        expansion_order.append(node.state)

        if verbose:
            print(f"Expandiendo {node.state}: g={node.cost}")

        if node.state == goal:
            return {
                "path": reconstruct_path(node),
                "expansion_order": expansion_order,
                "cost": node.cost
            }

        explored.add(node.state)

        for child_state, edge_cost in maze.neighbors(node.state):
            new_cost = node.cost + edge_cost

            if new_cost < best_cost.get(child_state, float("inf")):
                best_cost[child_state] = new_cost

                child = Node(
                    state=child_state,
                    parent=node,
                    cost=new_cost
                )

                frontier.add(child, priority=new_cost)

    return None

# %%
ucs_result = uniform_cost_search(maze1, start, goal)

print("Estados explorados:", len(ucs_result["expansion_order"]))
print("Longitud del camino:", len(ucs_result["path"]) - 1)
print("Costo óptimo:", ucs_result["cost"])

assert ucs_result["cost"] == 28

maze1.show(
    path=bfs_result["path"],
    explored=set(ucs_result["expansion_order"]),
    title="UCS: estados explorados y solución"
)
# Out:
# Estados explorados: 106
# Longitud del camino: 28
# Costo óptimo: 28

# %% [markdown]
# ## 7. Heurística para Greedy y A*
#
# $$
# h(n) \approx \text{costo restante estimado desde } n \text{ hasta la meta}
# $$
#
# En el grafo, la heurística era una **tabla fija** (`heuristic["A"] = 4`, etc.) porque los estados eran letras conocidas de antemano. En el laberinto los estados son coordenadas, así que expresamos \(h(n)\) como una **función de la coordenada**: la distancia Manhattan entre el estado y la meta.
#
# $$
# h(n) = |r_n - r_{\text{meta}}| + |c_n - c_{\text{meta}}|
# $$
#
# Esta es la segunda (y última) diferencia real respecto al notebook de grafos: donde antes escribíamos `heuristic[state]`, ahora escribimos `heuristic(state, goal)`.
#
# La heurística ignora los muros, por lo que puede subestimar la distancia real — nunca la sobrestima, así que sigue siendo **admisible** (y consistente, porque cada paso cuesta exactamente 1).

# %%
def manhattan(state, goal):
    return abs(state[0] - goal[0]) + abs(state[1] - goal[1])

print("h(inicio) =", manhattan(start, goal))
print("h(meta)   =", manhattan(goal, goal))
# Out:
# h(inicio) = 28
# h(meta)   = 0

# %% [markdown]
# ## 8. Greedy Best-First Search — actividad
#
# GBF utiliza únicamente:
#
# $$
# f(n) = h(n)
# $$
#
# ### Tareas
#
# 1. Reutilice `PriorityFrontier`.
# 2. Use la heurística como prioridad.
# 3. No use el costo acumulado para decidir qué nodo expandir.
# 4. Retorne el camino, orden de expansión y costo real del camino.

# %%
def greedy_best_first_search(maze, heuristic, start, goal, verbose=True):
    frontier = PriorityFrontier()

    nodo_inicio = Node(start, cost=0)
    frontier.add(nodo_inicio, priority=heuristic(start, goal))

    explored = set()
    expansion_order = []
    frontier_states = {start: nodo_inicio}


    while not frontier.empty():
        node, priority = frontier.remove()
        frontier_states.pop(node.state, None)

        expansion_order.append(node.state)

        if verbose:
            print(f"Expandiendo {node.state}: g={node.cost}")

        if node.state == goal:
            return {
                "path": reconstruct_path(node),
                "expansion_order": expansion_order,
                "cost": node.cost
            }

        explored.add(node.state)

        for child_state, edge_cost in maze.neighbors(node.state):
            if (child_state not in explored 
               and child_state not in frontier_states):
                
                child = Node(
                    state=child_state,
                    parent=node,
                    cost=node.cost + edge_cost
                )
                
                frontier.add(child, priority=heuristic(child_state, goal))
                frontier_states[child_state] = child

    return None

# %%
greedy_result = greedy_best_first_search(maze1, manhattan, start, goal)

print("Estados explorados:", len(greedy_result["expansion_order"]))
print("Longitud del camino:", len(greedy_result["path"]) - 1)
print("Costo del camino:", greedy_result["cost"])

maze1.show(
    path=greedy_result["path"],
    explored=set(greedy_result["expansion_order"]),
    title="Greedy Best-First Search"
)
# Out:
# Expandiendo (1, 1): g=0
# Expandiendo (2, 1): g=1
# Expandiendo (3, 1): g=2
# Expandiendo (4, 1): g=3
# Expandiendo (5, 1): g=4
# Expandiendo (6, 1): g=5
# Expandiendo (7, 1): g=6
# Expandiendo (7, 2): g=7
# Expandiendo (7, 3): g=8
# Expandiendo (8, 3): g=9
# Expandiendo (9, 3): g=10
# Expandiendo (10, 3): g=11
# Expandiendo (11, 3): g=12
# Expandiendo (12, 3): g=13
# Expandiendo (13, 3): g=14
# Expandiendo (14, 3): g=15
# Expandiendo (15, 3): g=16
# Expandiendo (15, 4): g=17
# Expandiendo (15, 5): g=18
# Expandiendo (14, 5): g=19
# Expandiendo (13, 5): g=20
# Expandiendo (13, 6): g=21
# Expandiendo (13, 7): g=22
# Expandiendo (13, 8): g=23
# Expandiendo (13, 9): g=24
# Expandiendo (14, 9): g=25
# Expandiendo (15, 9): g=26
# Expandiendo (15, 10): g=27
# Expandiendo (15, 11): g=28
# Expandiendo (15, 12): g=29
# Expandiendo (15, 13): g=30
# Expandiendo (15, 14): g=31
# Expandiendo (15, 15): g=32
# Estados explorados: 33
# Longitud del camino: 32
# Costo del camino: 32

# %%
# Pruebas públicas para Greedy
assert greedy_result["path"][0] == start
assert greedy_result["path"][-1] == goal
assert greedy_result["cost"] == 32

print("✓ Greedy pasó las pruebas.")
# Out:
# ✓ Greedy pasó las pruebas.

# %% [markdown]
# ### La trampa de Greedy
#
# Greedy exploró muy pocos estados (comparado con BFS/UCS), pero su camino cuesta **32**, no **28** como el óptimo. `maze1` fue construido específicamente para mostrar esto: cerca de la meta hay un pasillo que *parece* prometedor según la distancia Manhattan, pero que obliga a un rodeo. Greedy entra ahí porque solo mira $h(n)$ y nunca reconsidera lo que ya gastó en $g(n)$.

# %% [markdown]
# ## 9. A* — actividad
#
# A* combina costo acumulado y heurística:
#
# $$
# f(n) = g(n) + h(n)
# $$
#
# ### Tareas
#
# 1. Adapte la implementación de UCS.
# 2. Mantenga `best_cost` para permitir mejoras de ruta.
# 3. Use `new_cost + heuristic(child_state, goal)` como prioridad.
# 4. Verifique que encuentre un camino óptimo.

# %%
def a_star_search(maze, heuristic, start, goal, verbose=True):
    frontier = PriorityFrontier()
    frontier.add(Node(start, cost=0), priority=heuristic(start, goal))

    # Mejor costo conocido para cada estado.
    best_cost = {start: 0}

    explored = set()
    expansion_order = []

    while not frontier.empty():
        node, priority = frontier.remove()

        # Ignorar entradas antiguas de la cola de prioridad.
        if node.cost != best_cost.get(node.state):
            continue

        expansion_order.append(node.state)

        if verbose:
            print(f"Expandiendo {node.state}: g={node.cost}")

        if node.state == goal:
            return {
                "path": reconstruct_path(node),
                "expansion_order": expansion_order,
                "cost": node.cost
            }

        explored.add(node.state)

        for child_state, edge_cost in maze.neighbors(node.state):
            new_cost = node.cost + edge_cost

            if new_cost < best_cost.get(child_state, float("inf")):
                best_cost[child_state] = new_cost

                child = Node(
                    state=child_state,
                    parent=node,
                    cost=new_cost
                )

                frontier.add(child, priority= new_cost+heuristic(child_state, goal))

    return None

# %%
astar_result = a_star_search(maze1, manhattan, start, goal)

print("Estados explorados:", len(astar_result["expansion_order"]))
print("Longitud del camino:", len(astar_result["path"]) - 1)
print("Costo óptimo:", astar_result["cost"])

maze1.show(
    path=astar_result["path"],
    explored=set(astar_result["expansion_order"]),
    title="A* con distancia Manhattan"
)
# Out:
# Expandiendo (1, 1): g=0
# Expandiendo (2, 1): g=1
# Expandiendo (1, 2): g=1
# Expandiendo (3, 1): g=2
# Expandiendo (1, 3): g=2
# Expandiendo (4, 1): g=3
# Expandiendo (3, 2): g=3
# Expandiendo (1, 4): g=3
# Expandiendo (5, 1): g=4
# Expandiendo (3, 3): g=4
# Expandiendo (1, 5): g=4
# Expandiendo (6, 1): g=5
# Expandiendo (5, 2): g=5
# Expandiendo (3, 4): g=5
# Expandiendo (2, 5): g=5
# Expandiendo (7, 1): g=6
# Expandiendo (5, 3): g=6
# Expandiendo (3, 5): g=6
# Expandiendo (7, 2): g=7
# Expandiendo (5, 4): g=7
# Expandiendo (7, 3): g=8
# Expandiendo (5, 5): g=8
# Expandiendo (8, 3): g=9
# Expandiendo (7, 4): g=9
# Expandiendo (6, 5): g=9
# Expandiendo (5, 6): g=9
# Expandiendo (9, 3): g=10
# Expandiendo (7, 5): g=10
# Expandiendo (5, 7): g=10
# Expandiendo (10, 3): g=11
# Expandiendo (8, 5): g=11
# Expandiendo (5, 8): g=11
# Expandiendo (11, 3): g=12
# Expandiendo (9, 5): g=12
# Expandiendo (5, 9): g=12
# Expandiendo (12, 3): g=13
# Expandiendo (10, 5): g=13
# Expandiendo (13, 3): g=14
# Expandiendo (11, 5): g=14
# Expandiendo (14, 3): g=15
# Expandiendo (13, 4): g=15
# Expandiendo (12, 5): g=15
# Expandiendo (15, 3): g=16
# Expandiendo (13, 5): g=16
# Expandiendo (15, 4): g=17
# Expandiendo (14, 5): g=17
# Expandiendo (13, 6): g=17
# Expandiendo (15, 5): g=18
# Expandiendo (13, 7): g=18
# Expandiendo (13, 8): g=19
# Expandiendo (13, 9): g=20
# Expandiendo (14, 9): g=21
# Expandiendo (15, 9): g=22
# Expandiendo (15, 10): g=23
# Expandiendo (15, 11): g=24
# Expandiendo (15, 12): g=25
# Expandiendo (15, 13): g=26
# Expandiendo (15, 14): g=27
# Expandiendo (15, 15): g=28
# Estados explorados: 59
# Longitud del camino: 28
# Costo óptimo: 28

# %%
# Pruebas públicas para A*
assert astar_result["path"][0] == start
assert astar_result["path"][-1] == goal
assert astar_result["cost"] == 28

print("✓ A* pasó las pruebas.")
# Out:
# ✓ A* pasó las pruebas.

# %% [markdown]
# ## 10. Comparación final
#
# Complete esta tabla después de ejecutar todos los algoritmos sobre `maze1`.
#
# | Algoritmo | Tipo de frontier | Prioridad | Estados explorados | Costo | ¿Óptimo? |
# |---|---|---|---:|---:|---:|
# | DFS | Pila | LIFO | 69 | 64 | No |
# | BFS | Cola | FIFO | 106 | 28 | Sí |
# | UCS | Cola de prioridad | \(g(n)\) | 106 | 28 | Sí |
# | Greedy | Cola de prioridad | \(h(n)\) | 33 | 32 | No |
# | A* | Cola de prioridad | \(g(n)+h(n)\) | 59 | 28 | Sí |
#
# ### Preguntas de cierre
#
# 1. ¿Qué algoritmos garantizan el camino de menor número de pasos? \
# Greedy
# 2. ¿Qué algoritmos garantizan el camino de menor costo?\
# BFS, UCS, A*
# 3. ¿Por qué Greedy puede encontrar un camino subóptimo aunque explore muy pocos estados?\
# Porque usa como prioridad la distancia hasta el estado final e intenta minimizar dicha distancia
# 4. ¿Qué ocurre con A* si \(h(n) = 0\) para todos los nodos? ¿En qué algoritmo del notebook de grafos se convertiría?\
# Se convierte en un UCS
# 5. ¿Qué efecto tiene el orden en que `neighbors()` genera las direcciones sobre DFS y BFS?\
# En si se exploran los estados con mayor profundidad o menos profundidad en la frontera
#
# ---
#
# # Parte 2 — Más allá de la traducción
#
# Todo lo anterior fue una traducción 1 a 1. Lo que sigue son experimentos que **no tienen equivalente** en el grafo `A–H` porque dependen de que el problema viva en un espacio con estructura geométrica: más de un laberinto, costos que varían por región, y heurísticas que se pueden calcular en vez de tabular.

# %% [markdown]
# ## Comparación experimental sobre `maze1`
#
# Automatizamos la tabla de la sección anterior y agregamos una comparación visual del esfuerzo de búsqueda (estados explorados) de cada algoritmo.

# %%
def summarize_results(results):
    rows = []
    for name, result in results.items():
        rows.append({
            "algoritmo": name,
            "estados_explorados": len(result["expansion_order"]),
            "longitud_camino": len(result["path"]) - 1,
            "costo_camino": result["cost"],
        })
    return rows

results_maze1 = {
    "DFS": dfs_result,
    "BFS": bfs_result,
    "UCS": ucs_result,
    "Greedy": greedy_result,
    "A*": astar_result,
}

summary_maze1 = summarize_results(results_maze1)
summary_maze1
# Out:
# [{'algoritmo': 'DFS',
#   'estados_explorados': 69,
#   'longitud_camino': 64,
#   'costo_camino': 64},
#  {'algoritmo': 'BFS',
#   'estados_explorados': 106,
#   'longitud_camino': 28,
#   'costo_camino': 28},
#  {'algoritmo': 'UCS',
#   'estados_explorados': 106,
#   'longitud_camino': 28,
#   'costo_camino': 28},
#  {'algoritmo': 'Greedy',
#   'estados_explorados': 33,
#   'longitud_camino': 32,
#   'costo_camino': 32},
#  {'algoritmo': 'A*',
#   'estados_explorados': 59,
#   'longitud_camino': 28,
#   'costo_camino': 28}]

# %%
algorithms = [row["algoritmo"] for row in summary_maze1]
explored_counts = [row["estados_explorados"] for row in summary_maze1]

plt.figure(figsize=(8, 4))
plt.bar(algorithms, explored_counts)
plt.ylabel("Estados explorados")
plt.title("Comparación de esfuerzo de búsqueda — maze1")
plt.show()

# %% [markdown]
# ## Experimento: una heurística no admisible
#
# Podemos multiplicar Manhattan por un factor mayor que 1:
#
# $$
# h'(n) = w \cdot h(n), \qquad w > 1
# $$
#
# Esta heurística puede **sobreestimar** el costo real, así que deja de ser admisible. El algoritmo suele comportarse de forma más agresiva y explorar menos estados, pero pierde la garantía de optimalidad.

# %%
def weighted_manhattan(state, goal, weight=3):
    return weight * manhattan(state, goal)

maze2 = Maze("mazes/mazes/maze2.txt")
s2, g2 = maze2.start, maze2.goal

standard_astar = a_star_search(maze2, manhattan, s2, g2)
aggressive_astar = a_star_search(
    maze2,
    lambda state, goal: weighted_manhattan(state, goal, weight=3),
    s2, g2
)

print("A* estándar:")
print("  costo:", standard_astar["cost"], " explorados:", len(standard_astar["expansion_order"]))

print("A* con heurística ponderada (w=3):")
print("  costo:", aggressive_astar["cost"], " explorados:", len(aggressive_astar["expansion_order"]))

maze2.show(
    path=aggressive_astar["path"],
    explored=set(aggressive_astar["expansion_order"]),
    title="A* con heurística no admisible (w=3)"
)
# Out:
# Expandiendo (1, 1): g=0
# Expandiendo (1, 2): g=1
# Expandiendo (1, 3): g=2
# Expandiendo (2, 3): g=3
# Expandiendo (3, 3): g=4
# Expandiendo (4, 3): g=5
# Expandiendo (3, 4): g=5
# Expandiendo (5, 3): g=6
# Expandiendo (3, 5): g=6
# Expandiendo (3, 6): g=7
# Expandiendo (3, 7): g=8
# Expandiendo (4, 7): g=9
# Expandiendo (5, 7): g=10
# Expandiendo (5, 2): g=7
# Expandiendo (2, 5): g=7
# Expandiendo (2, 7): g=9
# Expandiendo (5, 6): g=11
# Expandiendo (5, 1): g=8
# Expandiendo (1, 5): g=8
# Expandiendo (1, 7): g=10
# Expandiendo (5, 5): g=12
# Expandiendo (6, 1): g=9
# Expandiendo (1, 6): g=9
# Expandiendo (1, 8): g=11
# Expandiendo (6, 5): g=13
# Expandiendo (7, 1): g=10
# Expandiendo (1, 9): g=12
# Expandiendo (7, 5): g=14
# Expandiendo (7, 2): g=11
# Expandiendo (1, 10): g=13
# Expandiendo (8, 5): g=15
# Expandiendo (7, 3): g=12
# Expandiendo (1, 11): g=14
# Expandiendo (9, 5): g=16
# Expandiendo (8, 3): g=13
# Expandiendo (2, 11): g=15
# Expandiendo (1, 12): g=15
# Expandiendo (10, 5): g=17
# Expandiendo (9, 3): g=14
# Expandiendo (3, 11): g=16
# Expandiendo (1, 13): g=16
# Expandiendo (11, 5): g=18
# Expandiendo (10, 3): g=15
# Expandiendo (4, 11): g=17
# Expandiendo (2, 13): g=17
# Expandiendo (1, 14): g=17
# Expandiendo (12, 5): g=19
# Expandiendo (11, 6): g=19
# Expandiendo (11, 3): g=16
# Expandiendo (5, 11): g=18
# Expandiendo (3, 13): g=18
# Expandiendo (1, 15): g=18
# Expandiendo (13, 5): g=20
# Expandiendo (11, 7): g=20
# Expandiendo (11, 4): g=17
# Expandiendo (6, 11): g=19
# Expandiendo (5, 12): g=19
# Expandiendo (4, 13): g=19
# Expandiendo (2, 15): g=19
# Expandiendo (1, 16): g=19
# Expandiendo (14, 5): g=21
# Expandiendo (12, 7): g=21
# Expandiendo (11, 8): g=21
# Expandiendo (7, 11): g=20
# Expandiendo (5, 13): g=20
# Expandiendo (3, 15): g=20
# Expandiendo (1, 17): g=20
# Expandiendo (15, 5): g=22
# Expandiendo (13, 7): g=22
# Expandiendo (11, 9): g=22
# Expandiendo (8, 11): g=21
# Expandiendo (7, 12): g=21
# Expandiendo (6, 13): g=21
# Expandiendo (4, 15): g=21
# Expandiendo (2, 17): g=21
# Expandiendo (14, 7): g=23
# Expandiendo (12, 9): g=23
# Expandiendo (9, 11): g=22
# Expandiendo (7, 13): g=22
# Expandiendo (5, 15): g=22
# Expandiendo (3, 17): g=22
# Expandiendo (15, 7): g=24
# Expandiendo (13, 9): g=24
# Expandiendo (10, 11): g=23
# Expandiendo (9, 12): g=23
# Expandiendo (8, 13): g=23
# Expandiendo (6, 15): g=23
# Expandiendo (5, 16): g=23
# Expandiendo (16, 7): g=25
# Expandiendo (15, 8): g=25
# Expandiendo (13, 10): g=25
# Expandiendo (11, 11): g=24
# Expandiendo (9, 13): g=24
# Expandiendo (7, 15): g=24
# Expandiendo (5, 17): g=24
# Expandiendo (17, 7): g=26
# Expandiendo (15, 9): g=26
# Expandiendo (13, 11): g=26
# Expandiendo (11, 12): g=25
# Expandiendo (8, 15): g=25
# Expandiendo (7, 16): g=25
# Expandiendo (6, 17): g=25
# Expandiendo (16, 9): g=27
# Expandiendo (15, 10): g=27
# Expandiendo (14, 11): g=27
# Expandiendo (13, 12): g=27
# Expandiendo (11, 13): g=26
# Expandiendo (9, 15): g=26
# Expandiendo (7, 17): g=26
# Expandiendo (17, 9): g=28
# Expandiendo (15, 11): g=28
# Expandiendo (13, 13): g=28
# Expandiendo (12, 13): g=27
# Expandiendo (10, 15): g=27
# Expandiendo (8, 17): g=27
# Expandiendo (17, 10): g=29
# Expandiendo (14, 13): g=29
# Expandiendo (11, 15): g=28
# Expandiendo (9, 17): g=28
# Expandiendo (17, 11): g=30
# Expandiendo (15, 13): g=30
# Expandiendo (12, 15): g=29
# Expandiendo (11, 16): g=29
# Expandiendo (10, 17): g=29
# Expandiendo (17, 12): g=31
# Expandiendo (16, 13): g=31
# Expandiendo (13, 15): g=30
# Expandiendo (11, 17): g=30
# Expandiendo (17, 13): g=32
# Expandiendo (14, 15): g=31
# Expandiendo (12, 17): g=31
# Expandiendo (17, 14): g=33
# Expandiendo (15, 15): g=32
# Expandiendo (13, 17): g=32
# Expandiendo (17, 15): g=34
# Expandiendo (16, 15): g=33
# Expandiendo (15, 16): g=33
# Expandiendo (14, 17): g=33
# Expandiendo (15, 17): g=34
# Expandiendo (16, 17): g=35
# Expandiendo (17, 17): g=36
# Expandiendo (1, 1): g=0
# Expandiendo (1, 2): g=1
# Expandiendo (1, 3): g=2
# Expandiendo (2, 3): g=3
# Expandiendo (3, 3): g=4
# Expandiendo (4, 3): g=5
# Expandiendo (5, 3): g=6
# Expandiendo (3, 4): g=5
# Expandiendo (3, 5): g=6
# Expandiendo (3, 6): g=7
# Expandiendo (3, 7): g=8
# Expandiendo (4, 7): g=9
# Expandiendo (5, 7): g=10
# Expandiendo (5, 6): g=11
# Expandiendo (2, 7): g=9
# Expandiendo (5, 5): g=12
# Expandiendo (6, 5): g=13
# Expandiendo (7, 5): g=14
# Expandiendo (8, 5): g=15
# Expandiendo (9, 5): g=16
# Expandiendo (10, 5): g=17
# Expandiendo (11, 5): g=18
# Expandiendo (12, 5): g=19
# Expandiendo (13, 5): g=20
# Expandiendo (14, 5): g=21
# Expandiendo (15, 5): g=22
# Expandiendo (15, 4): g=23
# Expandiendo (11, 6): g=19
# Expandiendo (11, 7): g=20
# Expandiendo (12, 7): g=21
# Expandiendo (13, 7): g=22
# Expandiendo (14, 7): g=23
# Expandiendo (15, 7): g=24
# Expandiendo (16, 7): g=25
# Expandiendo (17, 7): g=26
# Expandiendo (15, 8): g=25
# Expandiendo (15, 9): g=26
# Expandiendo (16, 9): g=27
# Expandiendo (17, 9): g=28
# Expandiendo (17, 10): g=29
# Expandiendo (17, 11): g=30
# Expandiendo (17, 12): g=31
# Expandiendo (17, 13): g=32
# Expandiendo (17, 14): g=33
# Expandiendo (17, 15): g=34
# Expandiendo (16, 15): g=35
# Expandiendo (16, 13): g=33
# Expandiendo (15, 15): g=36
# Expandiendo (15, 16): g=37
# Expandiendo (15, 17): g=38
# Expandiendo (16, 17): g=39
# Expandiendo (17, 17): g=40
# A* estándar:
#   costo: 36  explorados: 141
# A* con heurística ponderada (w=3):
#   costo: 40  explorados: 52

# %% [markdown]
# La versión ponderada exploró **muchos menos estados** (52 frente a 141), pero encontró un camino de costo **40** en vez del óptimo **36**. Es el mismo fenómeno que Greedy en `maze1`, en un extremo distinto del espectro: entre más peso le damos a \(h(n)\) frente a \(g(n)\), más rápido pero menos confiable se vuelve A*. Con \(w=1\) recuperamos A* estándar; con \(w \to \infty\) nos acercamos a Greedy puro.

# %% [markdown]
# ## Comparación en los tres laberintos
#
# Ejecutamos los cinco algoritmos sobre `maze1`, `maze2` y `maze3` para observar cómo cambia el esfuerzo de búsqueda según la estructura de cada laberinto (más o menos ciclos, más o menos pasillos largos).

# %%
def run_all(maze):
    start, goal = maze.start, maze.goal
    return {
        "DFS": depth_first_search(maze, start, goal),
        "BFS": breadth_first_search(maze, start, goal),
        "UCS": uniform_cost_search(maze, start, goal),
        "Greedy": greedy_best_first_search(maze, manhattan, start, goal),
        "A*": a_star_search(maze, manhattan, start, goal),
    }

all_summaries = []
for filename in ["mazes/mazes/maze1.txt", "mazes/mazes/maze2.txt", "mazes/mazes/maze3.txt"]:
    current_maze = Maze(filename)
    current_results = run_all(current_maze)
    for row in summarize_results(current_results):
        row["laberinto"] = filename
        all_summaries.append(row)

all_summaries
# Out:
# Expandiendo: (1, 1)
# Frontier después de expandir: [(2, 1), (1, 2)]
# ---------------------------------------------
# Expandiendo: (2, 1)
# Frontier después de expandir: [(1, 2), (3, 1)]
# ---------------------------------------------
# Expandiendo: (1, 2)
# Frontier después de expandir: [(3, 1), (1, 3)]
# ---------------------------------------------
# Expandiendo: (3, 1)
# Frontier después de expandir: [(1, 3), (4, 1), (3, 2)]
# ---------------------------------------------
# Expandiendo: (1, 3)
# Frontier después de expandir: [(4, 1), (3, 2), (1, 4)]
# ---------------------------------------------
# Expandiendo: (4, 1)
# Frontier después de expandir: [(3, 2), (1, 4), (5, 1)]
# ---------------------------------------------
# Expandiendo: (3, 2)
# Frontier después de expandir: [(1, 4), (5, 1), (3, 3)]
# ---------------------------------------------
# Expandiendo: (1, 4)
# Frontier después de expandir: [(5, 1), (3, 3), (1, 5)]
# ---------------------------------------------
# Expandiendo: (5, 1)
# Frontier después de expandir: [(3, 3), (1, 5), (6, 1), (5, 2)]
# ---------------------------------------------
# Expandiendo: (3, 3)
# Frontier después de expandir: [(1, 5), (6, 1), (5, 2), (3, 4)]
# ---------------------------------------------
# Expandiendo: (1, 5)
# Frontier después de expandir: [(6, 1), (5, 2), (3, 4), (2, 5)]
# ---------------------------------------------
# Expandiendo: (6, 1)
# Frontier después de expandir: [(5, 2), (3, 4), (2, 5), (7, 1)]
# ---------------------------------------------
# Expandiendo: (5, 2)
# Frontier después de expandir: [(3, 4), (2, 5), (7, 1), (5, 3)]
# ---------------------------------------------
# Expandiendo: (3, 4)
# Frontier después de expandir: [(2, 5), (7, 1), (5, 3), (3, 5)]
# ---------------------------------------------
# Expandiendo: (2, 5)
# Frontier después de expandir: [(7, 1), (5, 3), (3, 5)]
# ---------------------------------------------
# Expandiendo: (7, 1)
# Frontier después de expandir: [(5, 3), (3, 5), (7, 2)]
# ---------------------------------------------
# Expandiendo: (5, 3)
# Frontier después de expandir: [(3, 5), (7, 2), (5, 4)]
# ---------------------------------------------
# Expandiendo: (3, 5)
# Frontier después de expandir: [(7, 2), (5, 4)]
# ---------------------------------------------
# Expandiendo: (7, 2)
# Frontier después de expandir: [(5, 4), (7, 3)]
# ---------------------------------------------
# Expandiendo: (5, 4)
# Frontier después de expandir: [(7, 3), (5, 5)]
# ---------------------------------------------
# Expandiendo: (7, 3)
# Frontier después de expandir: [(5, 5), (8, 3), (7, 4)]
# ---------------------------------------------
# Expandiendo: (5, 5)
# Frontier después de expandir: [(8, 3), (7, 4), (6, 5), (5, 6)]
# ---------------------------------------------
# Expandiendo: (8, 3)
# Frontier después de expandir: [(7, 4), (6, 5), (5, 6), (9, 3)]
# ---------------------------------------------
# Expandiendo: (7, 4)
# Frontier después de expandir: [(6, 5), (5, 6), (9, 3), (7, 5)]
# ---------------------------------------------
# Expandiendo: (6, 5)
# Frontier después de expandir: [(5, 6), (9, 3), (7, 5)]
# ---------------------------------------------
# Expandiendo: (5, 6)
# Frontier después de expandir: [(9, 3), (7, 5), (5, 7)]
# ---------------------------------------------
# Expandiendo: (9, 3)
# Frontier después de expandir: [(7, 5), (5, 7), (10, 3)]
# ---------------------------------------------
# Expandiendo: (7, 5)
# Frontier después de expandir: [(5, 7), (10, 3), (8, 5)]
# ---------------------------------------------
# Expandiendo: (5, 7)
# Frontier después de expandir: [(10, 3), (8, 5), (5, 8)]
# ---------------------------------------------
# Expandiendo: (10, 3)
# Frontier después de expandir: [(8, 5), (5, 8), (11, 3)]
# ---------------------------------------------
# Expandiendo: (8, 5)
# Frontier después de expandir: [(5, 8), (11, 3), (9, 5)]
# ---------------------------------------------
# Expandiendo: (5, 8)
# Frontier después de expandir: [(11, 3), (9, 5), (5, 9)]
# ---------------------------------------------
# Expandiendo: (11, 3)
# Frontier después de expandir: [(9, 5), (5, 9), (12, 3)]
# ---------------------------------------------
# Expandiendo: (9, 5)
# Frontier después de expandir: [(5, 9), (12, 3), (10, 5)]
# ---------------------------------------------
# Expandiendo: (5, 9)
# Frontier después de expandir: [(12, 3), (10, 5), (4, 9)]
# ---------------------------------------------
# Expandiendo: (12, 3)
# Frontier después de expandir: [(10, 5), (4, 9), (13, 3)]
# ---------------------------------------------
# Expandiendo: (10, 5)
# Frontier después de expandir: [(4, 9), (13, 3), (11, 5)]
# ---------------------------------------------
# Expandiendo: (4, 9)
# Frontier después de expandir: [(13, 3), (11, 5), (3, 9)]
# ---------------------------------------------
# Expandiendo: (13, 3)
# Frontier después de expandir: [(11, 5), (3, 9), (14, 3), (13, 2), (13, 4)]
# ---------------------------------------------
# Expandiendo: (11, 5)
# Frontier después de expandir: [(3, 9), (14, 3), (13, 2), (13, 4), (12, 5)]
# ---------------------------------------------
# Expandiendo: (3, 9)
# Frontier después de expandir: [(14, 3), (13, 2), (13, 4), (12, 5), (3, 10)]
# ---------------------------------------------
# Expandiendo: (14, 3)
# Frontier después de expandir: [(13, 2), (13, 4), (12, 5), (3, 10), (15, 3)]
# ---------------------------------------------
# Expandiendo: (13, 2)
# Frontier después de expandir: [(13, 4), (12, 5), (3, 10), (15, 3), (13, 1)]
# ---------------------------------------------
# Expandiendo: (13, 4)
# Frontier después de expandir: [(12, 5), (3, 10), (15, 3), (13, 1), (13, 5)]
# ---------------------------------------------
# Expandiendo: (12, 5)
# Frontier después de expandir: [(3, 10), (15, 3), (13, 1), (13, 5)]
# ---------------------------------------------
# Expandiendo: (3, 10)
# Frontier después de expandir: [(15, 3), (13, 1), (13, 5), (3, 11)]
# ---------------------------------------------
# Expandiendo: (15, 3)
# Frontier después de expandir: [(13, 1), (13, 5), (3, 11), (15, 2), (15, 4)]
# ---------------------------------------------
# Expandiendo: (13, 1)
# Frontier después de expandir: [(13, 5), (3, 11), (15, 2), (15, 4), (12, 1), (14, 1)]
# ---------------------------------------------
# Expandiendo: (13, 5)
# Frontier después de expandir: [(3, 11), (15, 2), (15, 4), (12, 1), (14, 1), (14, 5), (13, 6)]
# ---------------------------------------------
# Expandiendo: (3, 11)
# Frontier después de expandir: [(15, 2), (15, 4), (12, 1), (14, 1), (14, 5), (13, 6), (4, 11)]
# ---------------------------------------------
# Expandiendo: (15, 2)
# Frontier después de expandir: [(15, 4), (12, 1), (14, 1), (14, 5), (13, 6), (4, 11), (15, 1)]
# ---------------------------------------------
# Expandiendo: (15, 4)
# Frontier después de expandir: [(12, 1), (14, 1), (14, 5), (13, 6), (4, 11), (15, 1), (15, 5)]
# ---------------------------------------------
# Expandiendo: (12, 1)
# Frontier después de expandir: [(14, 1), (14, 5), (13, 6), (4, 11), (15, 1), (15, 5), (11, 1)]
# ---------------------------------------------
# Expandiendo: (14, 1)
# Frontier después de expandir: [(14, 5), (13, 6), (4, 11), (15, 1), (15, 5), (11, 1)]
# ---------------------------------------------
# Expandiendo: (14, 5)
# Frontier después de expandir: [(13, 6), (4, 11), (15, 1), (15, 5), (11, 1)]
# ---------------------------------------------
# Expandiendo: (13, 6)
# Frontier después de expandir: [(4, 11), (15, 1), (15, 5), (11, 1), (13, 7)]
# ---------------------------------------------
# Expandiendo: (4, 11)
# Frontier después de expandir: [(15, 1), (15, 5), (11, 1), (13, 7), (5, 11)]
# ---------------------------------------------
# Expandiendo: (15, 1)
# Frontier después de expandir: [(15, 5), (11, 1), (13, 7), (5, 11)]
# ---------------------------------------------
# Expandiendo: (15, 5)
# Frontier después de expandir: [(11, 1), (13, 7), (5, 11)]
# ---------------------------------------------
# Expandiendo: (11, 1)
# Frontier después de expandir: [(13, 7), (5, 11), (10, 1)]
# ---------------------------------------------
# Expandiendo: (13, 7)
# Frontier después de expandir: [(5, 11), (10, 1), (12, 7), (13, 8)]
# ---------------------------------------------
# Expandiendo: (5, 11)
# Frontier después de expandir: [(10, 1), (12, 7), (13, 8), (6, 11)]
# ---------------------------------------------
# Expandiendo: (10, 1)
# Frontier después de expandir: [(12, 7), (13, 8), (6, 11), (9, 1)]
# ---------------------------------------------
# Expandiendo: (12, 7)
# Frontier después de expandir: [(13, 8), (6, 11), (9, 1), (11, 7)]
# ---------------------------------------------
# Expandiendo: (13, 8)
# Frontier después de expandir: [(6, 11), (9, 1), (11, 7), (13, 9)]
# ---------------------------------------------
# Expandiendo: (6, 11)
# Frontier después de expandir: [(9, 1), (11, 7), (13, 9), (7, 11)]
# ---------------------------------------------
# Expandiendo: (9, 1)
# Frontier después de expandir: [(11, 7), (13, 9), (7, 11)]
# ---------------------------------------------
# Expandiendo: (11, 7)
# Frontier después de expandir: [(13, 9), (7, 11), (10, 7)]
# ---------------------------------------------
# Expandiendo: (13, 9)
# Frontier después de expandir: [(7, 11), (10, 7), (14, 9)]
# ---------------------------------------------
# Expandiendo: (7, 11)
# Frontier después de expandir: [(10, 7), (14, 9), (7, 12)]
# ---------------------------------------------
# Expandiendo: (10, 7)
# Frontier después de expandir: [(14, 9), (7, 12), (9, 7)]
# ---------------------------------------------
# Expandiendo: (14, 9)
# Frontier después de expandir: [(7, 12), (9, 7), (15, 9)]
# ---------------------------------------------
# Expandiendo: (7, 12)
# Frontier después de expandir: [(9, 7), (15, 9), (7, 13)]
# ---------------------------------------------
# Expandiendo: (9, 7)
# Frontier después de expandir: [(15, 9), (7, 13), (8, 7), (9, 8)]
# ---------------------------------------------
# Expandiendo: (15, 9)
# Frontier después de expandir: [(7, 13), (8, 7), (9, 8), (15, 8), (15, 10)]
# ---------------------------------------------
# Expandiendo: (7, 13)
# Frontier después de expandir: [(8, 7), (9, 8), (15, 8), (15, 10), (8, 13)]
# ---------------------------------------------
# Expandiendo: (8, 7)
# Frontier después de expandir: [(9, 8), (15, 8), (15, 10), (8, 13), (7, 7)]
# ---------------------------------------------
# Expandiendo: (9, 8)
# Frontier después de expandir: [(15, 8), (15, 10), (8, 13), (7, 7), (9, 9)]
# ---------------------------------------------
# Expandiendo: (15, 8)
# Frontier después de expandir: [(15, 10), (8, 13), (7, 7), (9, 9), (15, 7)]
# ---------------------------------------------
# Expandiendo: (15, 10)
# Frontier después de expandir: [(8, 13), (7, 7), (9, 9), (15, 7), (15, 11)]
# ---------------------------------------------
# Expandiendo: (8, 13)
# Frontier después de expandir: [(7, 7), (9, 9), (15, 7), (15, 11), (9, 13)]
# ---------------------------------------------
# Expandiendo: (7, 7)
# Frontier después de expandir: [(9, 9), (15, 7), (15, 11), (9, 13), (7, 8)]
# ---------------------------------------------
# Expandiendo: (9, 9)
# Frontier después de expandir: [(15, 7), (15, 11), (9, 13), (7, 8), (8, 9), (10, 9), (9, 10)]
# ---------------------------------------------
# Expandiendo: (15, 7)
# Frontier después de expandir: [(15, 11), (9, 13), (7, 8), (8, 9), (10, 9), (9, 10)]
# ---------------------------------------------
# Expandiendo: (15, 11)
# Frontier después de expandir: [(9, 13), (7, 8), (8, 9), (10, 9), (9, 10), (15, 12)]
# ---------------------------------------------
# Expandiendo: (9, 13)
# Frontier después de expandir: [(7, 8), (8, 9), (10, 9), (9, 10), (15, 12), (10, 13), (9, 14)]
# ---------------------------------------------
# Expandiendo: (7, 8)
# Frontier después de expandir: [(8, 9), (10, 9), (9, 10), (15, 12), (10, 13), (9, 14), (7, 9)]
# ---------------------------------------------
# Expandiendo: (8, 9)
# Frontier después de expandir: [(10, 9), (9, 10), (15, 12), (10, 13), (9, 14), (7, 9)]
# ---------------------------------------------
# Expandiendo: (10, 9)
# Frontier después de expandir: [(9, 10), (15, 12), (10, 13), (9, 14), (7, 9), (11, 9)]
# ---------------------------------------------
# Expandiendo: (9, 10)
# Frontier después de expandir: [(15, 12), (10, 13), (9, 14), (7, 9), (11, 9), (9, 11)]
# ---------------------------------------------
# Expandiendo: (15, 12)
# Frontier después de expandir: [(10, 13), (9, 14), (7, 9), (11, 9), (9, 11), (15, 13)]
# ---------------------------------------------
# Expandiendo: (10, 13)
# Frontier después de expandir: [(9, 14), (7, 9), (11, 9), (9, 11), (15, 13), (11, 13)]
# ---------------------------------------------
# Expandiendo: (9, 14)
# Frontier después de expandir: [(7, 9), (11, 9), (9, 11), (15, 13), (11, 13), (9, 15)]
# ---------------------------------------------
# Expandiendo: (7, 9)
# Frontier después de expandir: [(11, 9), (9, 11), (15, 13), (11, 13), (9, 15)]
# ---------------------------------------------
# Expandiendo: (11, 9)
# Frontier después de expandir: [(9, 11), (15, 13), (11, 13), (9, 15), (11, 10)]
# ---------------------------------------------
# Expandiendo: (9, 11)
# Frontier después de expandir: [(15, 13), (11, 13), (9, 15), (11, 10)]
# ---------------------------------------------
# Expandiendo: (15, 13)
# Frontier después de expandir: [(11, 13), (9, 15), (11, 10), (15, 14)]
# ---------------------------------------------
# Expandiendo: (11, 13)
# Frontier después de expandir: [(9, 15), (11, 10), (15, 14), (11, 14)]
# ---------------------------------------------
# Expandiendo: (9, 15)
# Frontier después de expandir: [(11, 10), (15, 14), (11, 14), (8, 15), (10, 15)]
# ---------------------------------------------
# Expandiendo: (11, 10)
# Frontier después de expandir: [(15, 14), (11, 14), (8, 15), (10, 15), (11, 11)]
# ---------------------------------------------
# Expandiendo: (15, 14)
# Frontier después de expandir: [(11, 14), (8, 15), (10, 15), (11, 11), (15, 15)]
# ---------------------------------------------
# Expandiendo: (11, 14)
# Frontier después de expandir: [(8, 15), (10, 15), (11, 11), (15, 15), (11, 15)]
# ---------------------------------------------
# Expandiendo: (8, 15)
# Frontier después de expandir: [(10, 15), (11, 11), (15, 15), (11, 15), (7, 15)]
# ---------------------------------------------
# Expandiendo: (10, 15)
# Frontier después de expandir: [(11, 11), (15, 15), (11, 15), (7, 15)]
# ---------------------------------------------
# Expandiendo: (11, 11)
# Frontier después de expandir: [(15, 15), (11, 15), (7, 15), (12, 11)]
# ---------------------------------------------
# Expandiendo: (15, 15)
# Expandiendo (1, 1): g=0
# Expandiendo (2, 1): g=1
# Expandiendo (3, 1): g=2
# Expandiendo (4, 1): g=3
# Expandiendo (5, 1): g=4
# Expandiendo (6, 1): g=5
# Expandiendo (7, 1): g=6
# Expandiendo (7, 2): g=7
# Expandiendo (7, 3): g=8
# Expandiendo (8, 3): g=9
# Expandiendo (9, 3): g=10
# Expandiendo (10, 3): g=11
# Expandiendo (11, 3): g=12
# Expandiendo (12, 3): g=13
# Expandiendo (13, 3): g=14
# Expandiendo (14, 3): g=15
# Expandiendo (15, 3): g=16
# Expandiendo (15, 4): g=17
# Expandiendo (15, 5): g=18
# Expandiendo (14, 5): g=19
# Expandiendo (13, 5): g=20
# Expandiendo (13, 6): g=21
# Expandiendo (13, 7): g=22
# Expandiendo (13, 8): g=23
# Expandiendo (13, 9): g=24
# Expandiendo (14, 9): g=25
# Expandiendo (15, 9): g=26
# Expandiendo (15, 10): g=27
# Expandiendo (15, 11): g=28
# Expandiendo (15, 12): g=29
# Expandiendo (15, 13): g=30
# Expandiendo (15, 14): g=31
# Expandiendo (15, 15): g=32
# Expandiendo (1, 1): g=0
# Expandiendo (2, 1): g=1
# Expandiendo (1, 2): g=1
# Expandiendo (3, 1): g=2
# Expandiendo (1, 3): g=2
# Expandiendo (4, 1): g=3
# Expandiendo (3, 2): g=3
# Expandiendo (1, 4): g=3
# Expandiendo (5, 1): g=4
# Expandiendo (3, 3): g=4
# Expandiendo (1, 5): g=4
# Expandiendo (6, 1): g=5
# Expandiendo (5, 2): g=5
# Expandiendo (3, 4): g=5
# Expandiendo (2, 5): g=5
# Expandiendo (7, 1): g=6
# Expandiendo (5, 3): g=6
# Expandiendo (3, 5): g=6
# Expandiendo (7, 2): g=7
# Expandiendo (5, 4): g=7
# Expandiendo (7, 3): g=8
# Expandiendo (5, 5): g=8
# Expandiendo (8, 3): g=9
# Expandiendo (7, 4): g=9
# Expandiendo (6, 5): g=9
# Expandiendo (5, 6): g=9
# Expandiendo (9, 3): g=10
# Expandiendo (7, 5): g=10
# Expandiendo (5, 7): g=10
# Expandiendo (10, 3): g=11
# Expandiendo (8, 5): g=11
# Expandiendo (5, 8): g=11
# Expandiendo (11, 3): g=12
# Expandiendo (9, 5): g=12
# Expandiendo (5, 9): g=12
# Expandiendo (12, 3): g=13
# Expandiendo (10, 5): g=13
# Expandiendo (13, 3): g=14
# Expandiendo (11, 5): g=14
# Expandiendo (14, 3): g=15
# Expandiendo (13, 4): g=15
# Expandiendo (12, 5): g=15
# Expandiendo (15, 3): g=16
# Expandiendo (13, 5): g=16
# Expandiendo (15, 4): g=17
# Expandiendo (14, 5): g=17
# Expandiendo (13, 6): g=17
# Expandiendo (15, 5): g=18
# Expandiendo (13, 7): g=18
# Expandiendo (13, 8): g=19
# Expandiendo (13, 9): g=20
# Expandiendo (14, 9): g=21
# Expandiendo (15, 9): g=22
# Expandiendo (15, 10): g=23
# Expandiendo (15, 11): g=24
# Expandiendo (15, 12): g=25
# Expandiendo (15, 13): g=26
# Expandiendo (15, 14): g=27
# Expandiendo (15, 15): g=28
# Expandiendo: (1, 1)
# Frontier después de expandir: [(1, 2)]
# ---------------------------------------------
# Expandiendo: (1, 2)
# Frontier después de expandir: [(1, 3)]
# ---------------------------------------------
# Expandiendo: (1, 3)
# Frontier después de expandir: [(2, 3)]
# ---------------------------------------------
# Expandiendo: (2, 3)
# Frontier después de expandir: [(3, 3)]
# ---------------------------------------------
# Expandiendo: (3, 3)
# Frontier después de expandir: [(4, 3), (3, 4)]
# ---------------------------------------------
# Expandiendo: (4, 3)
# Frontier después de expandir: [(3, 4), (5, 3)]
# ---------------------------------------------
# Expandiendo: (3, 4)
# Frontier después de expandir: [(5, 3), (3, 5)]
# ---------------------------------------------
# Expandiendo: (5, 3)
# Frontier después de expandir: [(3, 5), (5, 2)]
# ---------------------------------------------
# Expandiendo: (3, 5)
# Frontier después de expandir: [(5, 2), (2, 5), (3, 6)]
# ---------------------------------------------
# Expandiendo: (5, 2)
# Frontier después de expandir: [(2, 5), (3, 6), (5, 1)]
# ---------------------------------------------
# Expandiendo: (2, 5)
# Frontier después de expandir: [(3, 6), (5, 1), (1, 5)]
# ---------------------------------------------
# Expandiendo: (3, 6)
# Frontier después de expandir: [(5, 1), (1, 5), (3, 7)]
# ---------------------------------------------
# Expandiendo: (5, 1)
# Frontier después de expandir: [(1, 5), (3, 7), (4, 1), (6, 1)]
# ---------------------------------------------
# Expandiendo: (1, 5)
# Frontier después de expandir: [(3, 7), (4, 1), (6, 1), (1, 6)]
# ---------------------------------------------
# Expandiendo: (3, 7)
# Frontier después de expandir: [(4, 1), (6, 1), (1, 6), (2, 7), (4, 7)]
# ---------------------------------------------
# Expandiendo: (4, 1)
# Frontier después de expandir: [(6, 1), (1, 6), (2, 7), (4, 7), (3, 1)]
# ---------------------------------------------
# Expandiendo: (6, 1)
# Frontier después de expandir: [(1, 6), (2, 7), (4, 7), (3, 1), (7, 1)]
# ---------------------------------------------
# Expandiendo: (1, 6)
# Frontier después de expandir: [(2, 7), (4, 7), (3, 1), (7, 1), (1, 7)]
# ---------------------------------------------
# Expandiendo: (2, 7)
# Frontier después de expandir: [(4, 7), (3, 1), (7, 1), (1, 7)]
# ---------------------------------------------
# Expandiendo: (4, 7)
# Frontier después de expandir: [(3, 1), (7, 1), (1, 7), (5, 7)]
# ---------------------------------------------
# Expandiendo: (3, 1)
# Frontier después de expandir: [(7, 1), (1, 7), (5, 7)]
# ---------------------------------------------
# Expandiendo: (7, 1)
# Frontier después de expandir: [(1, 7), (5, 7), (7, 2)]
# ---------------------------------------------
# Expandiendo: (1, 7)
# Frontier después de expandir: [(5, 7), (7, 2), (1, 8)]
# ---------------------------------------------
# Expandiendo: (5, 7)
# Frontier después de expandir: [(7, 2), (1, 8), (5, 6)]
# ---------------------------------------------
# Expandiendo: (7, 2)
# Frontier después de expandir: [(1, 8), (5, 6), (7, 3)]
# ---------------------------------------------
# Expandiendo: (1, 8)
# Frontier después de expandir: [(5, 6), (7, 3), (1, 9)]
# ---------------------------------------------
# Expandiendo: (5, 6)
# Frontier después de expandir: [(7, 3), (1, 9), (5, 5)]
# ---------------------------------------------
# Expandiendo: (7, 3)
# Frontier después de expandir: [(1, 9), (5, 5), (8, 3)]
# ---------------------------------------------
# Expandiendo: (1, 9)
# Frontier después de expandir: [(5, 5), (8, 3), (1, 10)]
# ---------------------------------------------
# Expandiendo: (5, 5)
# Frontier después de expandir: [(8, 3), (1, 10), (6, 5)]
# ---------------------------------------------
# Expandiendo: (8, 3)
# Frontier después de expandir: [(1, 10), (6, 5), (9, 3)]
# ---------------------------------------------
# Expandiendo: (1, 10)
# Frontier después de expandir: [(6, 5), (9, 3), (1, 11)]
# ---------------------------------------------
# Expandiendo: (6, 5)
# Frontier después de expandir: [(9, 3), (1, 11), (7, 5)]
# ---------------------------------------------
# Expandiendo: (9, 3)
# Frontier después de expandir: [(1, 11), (7, 5), (10, 3)]
# ---------------------------------------------
# Expandiendo: (1, 11)
# Frontier después de expandir: [(7, 5), (10, 3), (2, 11), (1, 12)]
# ---------------------------------------------
# Expandiendo: (7, 5)
# Frontier después de expandir: [(10, 3), (2, 11), (1, 12), (8, 5)]
# ---------------------------------------------
# Expandiendo: (10, 3)
# Frontier después de expandir: [(2, 11), (1, 12), (8, 5), (11, 3)]
# ---------------------------------------------
# Expandiendo: (2, 11)
# Frontier después de expandir: [(1, 12), (8, 5), (11, 3), (3, 11)]
# ---------------------------------------------
# Expandiendo: (1, 12)
# Frontier después de expandir: [(8, 5), (11, 3), (3, 11), (1, 13)]
# ---------------------------------------------
# Expandiendo: (8, 5)
# Frontier después de expandir: [(11, 3), (3, 11), (1, 13), (9, 5)]
# ---------------------------------------------
# Expandiendo: (11, 3)
# Frontier después de expandir: [(3, 11), (1, 13), (9, 5), (11, 4)]
# ---------------------------------------------
# Expandiendo: (3, 11)
# Frontier después de expandir: [(1, 13), (9, 5), (11, 4), (4, 11)]
# ---------------------------------------------
# Expandiendo: (1, 13)
# Frontier después de expandir: [(9, 5), (11, 4), (4, 11), (2, 13), (1, 14)]
# ---------------------------------------------
# Expandiendo: (9, 5)
# Frontier después de expandir: [(11, 4), (4, 11), (2, 13), (1, 14), (10, 5)]
# ---------------------------------------------
# Expandiendo: (11, 4)
# Frontier después de expandir: [(4, 11), (2, 13), (1, 14), (10, 5), (11, 5)]
# ---------------------------------------------
# Expandiendo: (4, 11)
# Frontier después de expandir: [(2, 13), (1, 14), (10, 5), (11, 5), (5, 11)]
# ---------------------------------------------
# Expandiendo: (2, 13)
# Frontier después de expandir: [(1, 14), (10, 5), (11, 5), (5, 11), (3, 13)]
# ---------------------------------------------
# Expandiendo: (1, 14)
# Frontier después de expandir: [(10, 5), (11, 5), (5, 11), (3, 13), (1, 15)]
# ---------------------------------------------
# Expandiendo: (10, 5)
# Frontier después de expandir: [(11, 5), (5, 11), (3, 13), (1, 15)]
# ---------------------------------------------
# Expandiendo: (11, 5)
# Frontier después de expandir: [(5, 11), (3, 13), (1, 15), (12, 5), (11, 6)]
# ---------------------------------------------
# Expandiendo: (5, 11)
# Frontier después de expandir: [(3, 13), (1, 15), (12, 5), (11, 6), (6, 11), (5, 12)]
# ---------------------------------------------
# Expandiendo: (3, 13)
# Frontier después de expandir: [(1, 15), (12, 5), (11, 6), (6, 11), (5, 12), (4, 13)]
# ---------------------------------------------
# Expandiendo: (1, 15)
# Frontier después de expandir: [(12, 5), (11, 6), (6, 11), (5, 12), (4, 13), (2, 15), (1, 16)]
# ---------------------------------------------
# Expandiendo: (12, 5)
# Frontier después de expandir: [(11, 6), (6, 11), (5, 12), (4, 13), (2, 15), (1, 16), (13, 5)]
# ---------------------------------------------
# Expandiendo: (11, 6)
# Frontier después de expandir: [(6, 11), (5, 12), (4, 13), (2, 15), (1, 16), (13, 5), (11, 7)]
# ---------------------------------------------
# Expandiendo: (6, 11)
# Frontier después de expandir: [(5, 12), (4, 13), (2, 15), (1, 16), (13, 5), (11, 7), (7, 11)]
# ---------------------------------------------
# Expandiendo: (5, 12)
# Frontier después de expandir: [(4, 13), (2, 15), (1, 16), (13, 5), (11, 7), (7, 11), (5, 13)]
# ---------------------------------------------
# Expandiendo: (4, 13)
# Frontier después de expandir: [(2, 15), (1, 16), (13, 5), (11, 7), (7, 11), (5, 13)]
# ---------------------------------------------
# Expandiendo: (2, 15)
# Frontier después de expandir: [(1, 16), (13, 5), (11, 7), (7, 11), (5, 13), (3, 15)]
# ---------------------------------------------
# Expandiendo: (1, 16)
# Frontier después de expandir: [(13, 5), (11, 7), (7, 11), (5, 13), (3, 15), (1, 17)]
# ---------------------------------------------
# Expandiendo: (13, 5)
# Frontier después de expandir: [(11, 7), (7, 11), (5, 13), (3, 15), (1, 17), (14, 5), (13, 4)]
# ---------------------------------------------
# Expandiendo: (11, 7)
# Frontier después de expandir: [(7, 11), (5, 13), (3, 15), (1, 17), (14, 5), (13, 4), (10, 7), (12, 7), (11, 8)]
# ---------------------------------------------
# Expandiendo: (7, 11)
# Frontier después de expandir: [(5, 13), (3, 15), (1, 17), (14, 5), (13, 4), (10, 7), (12, 7), (11, 8), (8, 11), (7, 10), (7, 12)]
# ---------------------------------------------
# Expandiendo: (5, 13)
# Frontier después de expandir: [(3, 15), (1, 17), (14, 5), (13, 4), (10, 7), (12, 7), (11, 8), (8, 11), (7, 10), (7, 12), (6, 13)]
# ---------------------------------------------
# Expandiendo: (3, 15)
# Frontier después de expandir: [(1, 17), (14, 5), (13, 4), (10, 7), (12, 7), (11, 8), (8, 11), (7, 10), (7, 12), (6, 13), (4, 15)]
# ---------------------------------------------
# Expandiendo: (1, 17)
# Frontier después de expandir: [(14, 5), (13, 4), (10, 7), (12, 7), (11, 8), (8, 11), (7, 10), (7, 12), (6, 13), (4, 15), (2, 17)]
# ---------------------------------------------
# Expandiendo: (14, 5)
# Frontier después de expandir: [(13, 4), (10, 7), (12, 7), (11, 8), (8, 11), (7, 10), (7, 12), (6, 13), (4, 15), (2, 17), (15, 5)]
# ---------------------------------------------
# Expandiendo: (13, 4)
# Frontier después de expandir: [(10, 7), (12, 7), (11, 8), (8, 11), (7, 10), (7, 12), (6, 13), (4, 15), (2, 17), (15, 5), (13, 3)]
# ---------------------------------------------
# Expandiendo: (10, 7)
# Frontier después de expandir: [(12, 7), (11, 8), (8, 11), (7, 10), (7, 12), (6, 13), (4, 15), (2, 17), (15, 5), (13, 3), (9, 7)]
# ---------------------------------------------
# Expandiendo: (12, 7)
# Frontier después de expandir: [(11, 8), (8, 11), (7, 10), (7, 12), (6, 13), (4, 15), (2, 17), (15, 5), (13, 3), (9, 7), (13, 7)]
# ---------------------------------------------
# Expandiendo: (11, 8)
# Frontier después de expandir: [(8, 11), (7, 10), (7, 12), (6, 13), (4, 15), (2, 17), (15, 5), (13, 3), (9, 7), (13, 7), (11, 9)]
# ---------------------------------------------
# Expandiendo: (8, 11)
# Frontier después de expandir: [(7, 10), (7, 12), (6, 13), (4, 15), (2, 17), (15, 5), (13, 3), (9, 7), (13, 7), (11, 9), (9, 11)]
# ---------------------------------------------
# Expandiendo: (7, 10)
# Frontier después de expandir: [(7, 12), (6, 13), (4, 15), (2, 17), (15, 5), (13, 3), (9, 7), (13, 7), (11, 9), (9, 11), (7, 9)]
# ---------------------------------------------
# Expandiendo: (7, 12)
# Frontier después de expandir: [(6, 13), (4, 15), (2, 17), (15, 5), (13, 3), (9, 7), (13, 7), (11, 9), (9, 11), (7, 9), (7, 13)]
# ---------------------------------------------
# Expandiendo: (6, 13)
# Frontier después de expandir: [(4, 15), (2, 17), (15, 5), (13, 3), (9, 7), (13, 7), (11, 9), (9, 11), (7, 9), (7, 13)]
# ---------------------------------------------
# Expandiendo: (4, 15)
# Frontier después de expandir: [(2, 17), (15, 5), (13, 3), (9, 7), (13, 7), (11, 9), (9, 11), (7, 9), (7, 13), (5, 15)]
# ---------------------------------------------
# Expandiendo: (2, 17)
# Frontier después de expandir: [(15, 5), (13, 3), (9, 7), (13, 7), (11, 9), (9, 11), (7, 9), (7, 13), (5, 15), (3, 17)]
# ---------------------------------------------
# Expandiendo: (15, 5)
# Frontier después de expandir: [(13, 3), (9, 7), (13, 7), (11, 9), (9, 11), (7, 9), (7, 13), (5, 15), (3, 17), (15, 4)]
# ---------------------------------------------
# Expandiendo: (13, 3)
# Frontier después de expandir: [(9, 7), (13, 7), (11, 9), (9, 11), (7, 9), (7, 13), (5, 15), (3, 17), (15, 4), (13, 2)]
# ---------------------------------------------
# Expandiendo: (9, 7)
# Frontier después de expandir: [(13, 7), (11, 9), (9, 11), (7, 9), (7, 13), (5, 15), (3, 17), (15, 4), (13, 2), (8, 7)]
# ---------------------------------------------
# Expandiendo: (13, 7)
# Frontier después de expandir: [(11, 9), (9, 11), (7, 9), (7, 13), (5, 15), (3, 17), (15, 4), (13, 2), (8, 7), (14, 7)]
# ---------------------------------------------
# Expandiendo: (11, 9)
# Frontier después de expandir: [(9, 11), (7, 9), (7, 13), (5, 15), (3, 17), (15, 4), (13, 2), (8, 7), (14, 7), (10, 9), (12, 9)]
# ---------------------------------------------
# Expandiendo: (9, 11)
# Frontier después de expandir: [(7, 9), (7, 13), (5, 15), (3, 17), (15, 4), (13, 2), (8, 7), (14, 7), (10, 9), (12, 9), (10, 11), (9, 12)]
# ---------------------------------------------
# Expandiendo: (7, 9)
# Frontier después de expandir: [(7, 13), (5, 15), (3, 17), (15, 4), (13, 2), (8, 7), (14, 7), (10, 9), (12, 9), (10, 11), (9, 12), (6, 9), (8, 9), (7, 8)]
# ---------------------------------------------
# Expandiendo: (7, 13)
# Frontier después de expandir: [(5, 15), (3, 17), (15, 4), (13, 2), (8, 7), (14, 7), (10, 9), (12, 9), (10, 11), (9, 12), (6, 9), (8, 9), (7, 8), (8, 13)]
# ---------------------------------------------
# Expandiendo: (5, 15)
# Frontier después de expandir: [(3, 17), (15, 4), (13, 2), (8, 7), (14, 7), (10, 9), (12, 9), (10, 11), (9, 12), (6, 9), (8, 9), (7, 8), (8, 13), (6, 15), (5, 16)]
# ---------------------------------------------
# Expandiendo: (3, 17)
# Frontier después de expandir: [(15, 4), (13, 2), (8, 7), (14, 7), (10, 9), (12, 9), (10, 11), (9, 12), (6, 9), (8, 9), (7, 8), (8, 13), (6, 15), (5, 16)]
# ---------------------------------------------
# Expandiendo: (15, 4)
# Frontier después de expandir: [(13, 2), (8, 7), (14, 7), (10, 9), (12, 9), (10, 11), (9, 12), (6, 9), (8, 9), (7, 8), (8, 13), (6, 15), (5, 16), (15, 3)]
# ---------------------------------------------
# Expandiendo: (13, 2)
# Frontier después de expandir: [(8, 7), (14, 7), (10, 9), (12, 9), (10, 11), (9, 12), (6, 9), (8, 9), (7, 8), (8, 13), (6, 15), (5, 16), (15, 3), (13, 1)]
# ---------------------------------------------
# Expandiendo: (8, 7)
# Frontier después de expandir: [(14, 7), (10, 9), (12, 9), (10, 11), (9, 12), (6, 9), (8, 9), (7, 8), (8, 13), (6, 15), (5, 16), (15, 3), (13, 1), (7, 7)]
# ---------------------------------------------
# Expandiendo: (14, 7)
# Frontier después de expandir: [(10, 9), (12, 9), (10, 11), (9, 12), (6, 9), (8, 9), (7, 8), (8, 13), (6, 15), (5, 16), (15, 3), (13, 1), (7, 7), (15, 7)]
# ---------------------------------------------
# Expandiendo: (10, 9)
# Frontier después de expandir: [(12, 9), (10, 11), (9, 12), (6, 9), (8, 9), (7, 8), (8, 13), (6, 15), (5, 16), (15, 3), (13, 1), (7, 7), (15, 7), (9, 9)]
# ---------------------------------------------
# Expandiendo: (12, 9)
# Frontier después de expandir: [(10, 11), (9, 12), (6, 9), (8, 9), (7, 8), (8, 13), (6, 15), (5, 16), (15, 3), (13, 1), (7, 7), (15, 7), (9, 9), (13, 9)]
# ---------------------------------------------
# Expandiendo: (10, 11)
# Frontier después de expandir: [(9, 12), (6, 9), (8, 9), (7, 8), (8, 13), (6, 15), (5, 16), (15, 3), (13, 1), (7, 7), (15, 7), (9, 9), (13, 9), (11, 11)]
# ---------------------------------------------
# Expandiendo: (9, 12)
# Frontier después de expandir: [(6, 9), (8, 9), (7, 8), (8, 13), (6, 15), (5, 16), (15, 3), (13, 1), (7, 7), (15, 7), (9, 9), (13, 9), (11, 11), (9, 13)]
# ---------------------------------------------
# Expandiendo: (6, 9)
# Frontier después de expandir: [(8, 9), (7, 8), (8, 13), (6, 15), (5, 16), (15, 3), (13, 1), (7, 7), (15, 7), (9, 9), (13, 9), (11, 11), (9, 13), (5, 9)]
# ---------------------------------------------
# Expandiendo: (8, 9)
# Frontier después de expandir: [(7, 8), (8, 13), (6, 15), (5, 16), (15, 3), (13, 1), (7, 7), (15, 7), (9, 9), (13, 9), (11, 11), (9, 13), (5, 9)]
# ---------------------------------------------
# Expandiendo: (7, 8)
# Frontier después de expandir: [(8, 13), (6, 15), (5, 16), (15, 3), (13, 1), (7, 7), (15, 7), (9, 9), (13, 9), (11, 11), (9, 13), (5, 9)]
# ---------------------------------------------
# Expandiendo: (8, 13)
# Frontier después de expandir: [(6, 15), (5, 16), (15, 3), (13, 1), (7, 7), (15, 7), (9, 9), (13, 9), (11, 11), (9, 13), (5, 9)]
# ---------------------------------------------
# Expandiendo: (6, 15)
# Frontier después de expandir: [(5, 16), (15, 3), (13, 1), (7, 7), (15, 7), (9, 9), (13, 9), (11, 11), (9, 13), (5, 9), (7, 15)]
# ---------------------------------------------
# Expandiendo: (5, 16)
# Frontier después de expandir: [(15, 3), (13, 1), (7, 7), (15, 7), (9, 9), (13, 9), (11, 11), (9, 13), (5, 9), (7, 15), (5, 17)]
# ---------------------------------------------
# Expandiendo: (15, 3)
# Frontier después de expandir: [(13, 1), (7, 7), (15, 7), (9, 9), (13, 9), (11, 11), (9, 13), (5, 9), (7, 15), (5, 17)]
# ---------------------------------------------
# Expandiendo: (13, 1)
# Frontier después de expandir: [(7, 7), (15, 7), (9, 9), (13, 9), (11, 11), (9, 13), (5, 9), (7, 15), (5, 17), (12, 1), (14, 1)]
# ---------------------------------------------
# Expandiendo: (7, 7)
# Frontier después de expandir: [(15, 7), (9, 9), (13, 9), (11, 11), (9, 13), (5, 9), (7, 15), (5, 17), (12, 1), (14, 1)]
# ---------------------------------------------
# Expandiendo: (15, 7)
# Frontier después de expandir: [(9, 9), (13, 9), (11, 11), (9, 13), (5, 9), (7, 15), (5, 17), (12, 1), (14, 1), (16, 7), (15, 8)]
# ---------------------------------------------
# Expandiendo: (9, 9)
# Frontier después de expandir: [(13, 9), (11, 11), (9, 13), (5, 9), (7, 15), (5, 17), (12, 1), (14, 1), (16, 7), (15, 8)]
# ---------------------------------------------
# Expandiendo: (13, 9)
# Frontier después de expandir: [(11, 11), (9, 13), (5, 9), (7, 15), (5, 17), (12, 1), (14, 1), (16, 7), (15, 8), (13, 10)]
# ---------------------------------------------
# Expandiendo: (11, 11)
# Frontier después de expandir: [(9, 13), (5, 9), (7, 15), (5, 17), (12, 1), (14, 1), (16, 7), (15, 8), (13, 10), (11, 12)]
# ---------------------------------------------
# Expandiendo: (9, 13)
# Frontier después de expandir: [(5, 9), (7, 15), (5, 17), (12, 1), (14, 1), (16, 7), (15, 8), (13, 10), (11, 12)]
# ---------------------------------------------
# Expandiendo: (5, 9)
# Frontier después de expandir: [(7, 15), (5, 17), (12, 1), (14, 1), (16, 7), (15, 8), (13, 10), (11, 12), (4, 9)]
# ---------------------------------------------
# Expandiendo: (7, 15)
# Frontier después de expandir: [(5, 17), (12, 1), (14, 1), (16, 7), (15, 8), (13, 10), (11, 12), (4, 9), (8, 15), (7, 16)]
# ---------------------------------------------
# Expandiendo: (5, 17)
# Frontier después de expandir: [(12, 1), (14, 1), (16, 7), (15, 8), (13, 10), (11, 12), (4, 9), (8, 15), (7, 16), (6, 17)]
# ---------------------------------------------
# Expandiendo: (12, 1)
# Frontier después de expandir: [(14, 1), (16, 7), (15, 8), (13, 10), (11, 12), (4, 9), (8, 15), (7, 16), (6, 17), (11, 1)]
# ---------------------------------------------
# Expandiendo: (14, 1)
# Frontier después de expandir: [(16, 7), (15, 8), (13, 10), (11, 12), (4, 9), (8, 15), (7, 16), (6, 17), (11, 1), (15, 1)]
# ---------------------------------------------
# Expandiendo: (16, 7)
# Frontier después de expandir: [(15, 8), (13, 10), (11, 12), (4, 9), (8, 15), (7, 16), (6, 17), (11, 1), (15, 1), (17, 7)]
# ---------------------------------------------
# Expandiendo: (15, 8)
# Frontier después de expandir: [(13, 10), (11, 12), (4, 9), (8, 15), (7, 16), (6, 17), (11, 1), (15, 1), (17, 7), (15, 9)]
# ---------------------------------------------
# Expandiendo: (13, 10)
# Frontier después de expandir: [(11, 12), (4, 9), (8, 15), (7, 16), (6, 17), (11, 1), (15, 1), (17, 7), (15, 9), (13, 11)]
# ---------------------------------------------
# Expandiendo: (11, 12)
# Frontier después de expandir: [(4, 9), (8, 15), (7, 16), (6, 17), (11, 1), (15, 1), (17, 7), (15, 9), (13, 11), (11, 13)]
# ---------------------------------------------
# Expandiendo: (4, 9)
# Frontier después de expandir: [(8, 15), (7, 16), (6, 17), (11, 1), (15, 1), (17, 7), (15, 9), (13, 11), (11, 13), (3, 9)]
# ---------------------------------------------
# Expandiendo: (8, 15)
# Frontier después de expandir: [(7, 16), (6, 17), (11, 1), (15, 1), (17, 7), (15, 9), (13, 11), (11, 13), (3, 9), (9, 15)]
# ---------------------------------------------
# Expandiendo: (7, 16)
# Frontier después de expandir: [(6, 17), (11, 1), (15, 1), (17, 7), (15, 9), (13, 11), (11, 13), (3, 9), (9, 15), (7, 17)]
# ---------------------------------------------
# Expandiendo: (6, 17)
# Frontier después de expandir: [(11, 1), (15, 1), (17, 7), (15, 9), (13, 11), (11, 13), (3, 9), (9, 15), (7, 17)]
# ---------------------------------------------
# Expandiendo: (11, 1)
# Frontier después de expandir: [(15, 1), (17, 7), (15, 9), (13, 11), (11, 13), (3, 9), (9, 15), (7, 17), (10, 1)]
# ---------------------------------------------
# Expandiendo: (15, 1)
# Frontier después de expandir: [(17, 7), (15, 9), (13, 11), (11, 13), (3, 9), (9, 15), (7, 17), (10, 1), (16, 1)]
# ---------------------------------------------
# Expandiendo: (17, 7)
# Frontier después de expandir: [(15, 9), (13, 11), (11, 13), (3, 9), (9, 15), (7, 17), (10, 1), (16, 1), (17, 6)]
# ---------------------------------------------
# Expandiendo: (15, 9)
# Frontier después de expandir: [(13, 11), (11, 13), (3, 9), (9, 15), (7, 17), (10, 1), (16, 1), (17, 6), (16, 9), (15, 10)]
# ---------------------------------------------
# Expandiendo: (13, 11)
# Frontier después de expandir: [(11, 13), (3, 9), (9, 15), (7, 17), (10, 1), (16, 1), (17, 6), (16, 9), (15, 10), (14, 11), (13, 12)]
# ---------------------------------------------
# Expandiendo: (11, 13)
# Frontier después de expandir: [(3, 9), (9, 15), (7, 17), (10, 1), (16, 1), (17, 6), (16, 9), (15, 10), (14, 11), (13, 12), (12, 13)]
# ---------------------------------------------
# Expandiendo: (3, 9)
# Frontier después de expandir: [(9, 15), (7, 17), (10, 1), (16, 1), (17, 6), (16, 9), (15, 10), (14, 11), (13, 12), (12, 13)]
# ---------------------------------------------
# Expandiendo: (9, 15)
# Frontier después de expandir: [(7, 17), (10, 1), (16, 1), (17, 6), (16, 9), (15, 10), (14, 11), (13, 12), (12, 13), (10, 15)]
# ---------------------------------------------
# Expandiendo: (7, 17)
# Frontier después de expandir: [(10, 1), (16, 1), (17, 6), (16, 9), (15, 10), (14, 11), (13, 12), (12, 13), (10, 15), (8, 17)]
# ---------------------------------------------
# Expandiendo: (10, 1)
# Frontier después de expandir: [(16, 1), (17, 6), (16, 9), (15, 10), (14, 11), (13, 12), (12, 13), (10, 15), (8, 17), (9, 1)]
# ---------------------------------------------
# Expandiendo: (16, 1)
# Frontier después de expandir: [(17, 6), (16, 9), (15, 10), (14, 11), (13, 12), (12, 13), (10, 15), (8, 17), (9, 1), (17, 1)]
# ---------------------------------------------
# Expandiendo: (17, 6)
# Frontier después de expandir: [(16, 9), (15, 10), (14, 11), (13, 12), (12, 13), (10, 15), (8, 17), (9, 1), (17, 1), (17, 5)]
# ---------------------------------------------
# Expandiendo: (16, 9)
# Frontier después de expandir: [(15, 10), (14, 11), (13, 12), (12, 13), (10, 15), (8, 17), (9, 1), (17, 1), (17, 5), (17, 9)]
# ---------------------------------------------
# Expandiendo: (15, 10)
# Frontier después de expandir: [(14, 11), (13, 12), (12, 13), (10, 15), (8, 17), (9, 1), (17, 1), (17, 5), (17, 9), (15, 11)]
# ---------------------------------------------
# Expandiendo: (14, 11)
# Frontier después de expandir: [(13, 12), (12, 13), (10, 15), (8, 17), (9, 1), (17, 1), (17, 5), (17, 9), (15, 11)]
# ---------------------------------------------
# Expandiendo: (13, 12)
# Frontier después de expandir: [(12, 13), (10, 15), (8, 17), (9, 1), (17, 1), (17, 5), (17, 9), (15, 11), (13, 13)]
# ---------------------------------------------
# Expandiendo: (12, 13)
# Frontier después de expandir: [(10, 15), (8, 17), (9, 1), (17, 1), (17, 5), (17, 9), (15, 11), (13, 13)]
# ---------------------------------------------
# Expandiendo: (10, 15)
# Frontier después de expandir: [(8, 17), (9, 1), (17, 1), (17, 5), (17, 9), (15, 11), (13, 13), (11, 15)]
# ---------------------------------------------
# Expandiendo: (8, 17)
# Frontier después de expandir: [(9, 1), (17, 1), (17, 5), (17, 9), (15, 11), (13, 13), (11, 15), (9, 17)]
# ---------------------------------------------
# Expandiendo: (9, 1)
# Frontier después de expandir: [(17, 1), (17, 5), (17, 9), (15, 11), (13, 13), (11, 15), (9, 17)]
# ---------------------------------------------
# Expandiendo: (17, 1)
# Frontier después de expandir: [(17, 5), (17, 9), (15, 11), (13, 13), (11, 15), (9, 17), (17, 2)]
# ---------------------------------------------
# Expandiendo: (17, 5)
# Frontier después de expandir: [(17, 9), (15, 11), (13, 13), (11, 15), (9, 17), (17, 2), (17, 4)]
# ---------------------------------------------
# Expandiendo: (17, 9)
# Frontier después de expandir: [(15, 11), (13, 13), (11, 15), (9, 17), (17, 2), (17, 4), (17, 10)]
# ---------------------------------------------
# Expandiendo: (15, 11)
# Frontier después de expandir: [(13, 13), (11, 15), (9, 17), (17, 2), (17, 4), (17, 10)]
# ---------------------------------------------
# Expandiendo: (13, 13)
# Frontier después de expandir: [(11, 15), (9, 17), (17, 2), (17, 4), (17, 10), (14, 13)]
# ---------------------------------------------
# Expandiendo: (11, 15)
# Frontier después de expandir: [(9, 17), (17, 2), (17, 4), (17, 10), (14, 13), (12, 15), (11, 16)]
# ---------------------------------------------
# Expandiendo: (9, 17)
# Frontier después de expandir: [(17, 2), (17, 4), (17, 10), (14, 13), (12, 15), (11, 16), (10, 17)]
# ---------------------------------------------
# Expandiendo: (17, 2)
# Frontier después de expandir: [(17, 4), (17, 10), (14, 13), (12, 15), (11, 16), (10, 17), (17, 3)]
# ---------------------------------------------
# Expandiendo: (17, 4)
# Frontier después de expandir: [(17, 10), (14, 13), (12, 15), (11, 16), (10, 17), (17, 3)]
# ---------------------------------------------
# Expandiendo: (17, 10)
# Frontier después de expandir: [(14, 13), (12, 15), (11, 16), (10, 17), (17, 3), (17, 11)]
# ---------------------------------------------
# Expandiendo: (14, 13)
# Frontier después de expandir: [(12, 15), (11, 16), (10, 17), (17, 3), (17, 11), (15, 13)]
# ---------------------------------------------
# Expandiendo: (12, 15)
# Frontier después de expandir: [(11, 16), (10, 17), (17, 3), (17, 11), (15, 13), (13, 15)]
# ---------------------------------------------
# Expandiendo: (11, 16)
# Frontier después de expandir: [(10, 17), (17, 3), (17, 11), (15, 13), (13, 15), (11, 17)]
# ---------------------------------------------
# Expandiendo: (10, 17)
# Frontier después de expandir: [(17, 3), (17, 11), (15, 13), (13, 15), (11, 17)]
# ---------------------------------------------
# Expandiendo: (17, 3)
# Frontier después de expandir: [(17, 11), (15, 13), (13, 15), (11, 17)]
# ---------------------------------------------
# Expandiendo: (17, 11)
# Frontier después de expandir: [(15, 13), (13, 15), (11, 17), (17, 12)]
# ---------------------------------------------
# Expandiendo: (15, 13)
# Frontier después de expandir: [(13, 15), (11, 17), (17, 12), (16, 13)]
# ---------------------------------------------
# Expandiendo: (13, 15)
# Frontier después de expandir: [(11, 17), (17, 12), (16, 13), (14, 15)]
# ---------------------------------------------
# Expandiendo: (11, 17)
# Frontier después de expandir: [(17, 12), (16, 13), (14, 15), (12, 17)]
# ---------------------------------------------
# Expandiendo: (17, 12)
# Frontier después de expandir: [(16, 13), (14, 15), (12, 17), (17, 13)]
# ---------------------------------------------
# Expandiendo: (16, 13)
# Frontier después de expandir: [(14, 15), (12, 17), (17, 13)]
# ---------------------------------------------
# Expandiendo: (14, 15)
# Frontier después de expandir: [(12, 17), (17, 13), (15, 15)]
# ---------------------------------------------
# Expandiendo: (12, 17)
# Frontier después de expandir: [(17, 13), (15, 15), (13, 17)]
# ---------------------------------------------
# Expandiendo: (17, 13)
# Frontier después de expandir: [(15, 15), (13, 17), (17, 14)]
# ---------------------------------------------
# Expandiendo: (15, 15)
# Frontier después de expandir: [(13, 17), (17, 14), (16, 15), (15, 16)]
# ---------------------------------------------
# Expandiendo: (13, 17)
# Frontier después de expandir: [(17, 14), (16, 15), (15, 16), (14, 17)]
# ---------------------------------------------
# Expandiendo: (17, 14)
# Frontier después de expandir: [(16, 15), (15, 16), (14, 17), (17, 15)]
# ---------------------------------------------
# Expandiendo: (16, 15)
# Frontier después de expandir: [(15, 16), (14, 17), (17, 15)]
# ---------------------------------------------
# Expandiendo: (15, 16)
# Frontier después de expandir: [(14, 17), (17, 15), (15, 17)]
# ---------------------------------------------
# Expandiendo: (14, 17)
# Frontier después de expandir: [(17, 15), (15, 17)]
# ---------------------------------------------
# Expandiendo: (17, 15)
# Frontier después de expandir: [(15, 17)]
# ---------------------------------------------
# Expandiendo: (15, 17)
# Frontier después de expandir: [(16, 17)]
# ---------------------------------------------
# Expandiendo: (16, 17)
# Frontier después de expandir: [(17, 17)]
# ---------------------------------------------
# Expandiendo: (17, 17)
# Expandiendo (1, 1): g=0
# Expandiendo (1, 2): g=1
# Expandiendo (1, 3): g=2
# Expandiendo (2, 3): g=3
# Expandiendo (3, 3): g=4
# Expandiendo (4, 3): g=5
# Expandiendo (5, 3): g=6
# Expandiendo (3, 4): g=5
# Expandiendo (3, 5): g=6
# Expandiendo (3, 6): g=7
# Expandiendo (3, 7): g=8
# Expandiendo (4, 7): g=9
# Expandiendo (5, 7): g=10
# Expandiendo (5, 6): g=11
# Expandiendo (5, 5): g=12
# Expandiendo (6, 5): g=13
# Expandiendo (7, 5): g=14
# Expandiendo (8, 5): g=15
# Expandiendo (9, 5): g=16
# Expandiendo (10, 5): g=17
# Expandiendo (11, 5): g=18
# Expandiendo (12, 5): g=19
# Expandiendo (13, 5): g=20
# Expandiendo (14, 5): g=21
# Expandiendo (15, 5): g=22
# Expandiendo (15, 4): g=23
# Expandiendo (15, 3): g=24
# Expandiendo (11, 6): g=19
# Expandiendo (11, 7): g=20
# Expandiendo (12, 7): g=21
# Expandiendo (13, 7): g=22
# Expandiendo (14, 7): g=23
# Expandiendo (15, 7): g=24
# Expandiendo (16, 7): g=25
# Expandiendo (17, 7): g=26
# Expandiendo (15, 8): g=25
# Expandiendo (15, 9): g=26
# Expandiendo (16, 9): g=27
# Expandiendo (17, 9): g=28
# Expandiendo (17, 10): g=29
# Expandiendo (17, 11): g=30
# Expandiendo (17, 12): g=31
# Expandiendo (17, 13): g=32
# Expandiendo (17, 14): g=33
# Expandiendo (17, 15): g=34
# Expandiendo (16, 15): g=35
# Expandiendo (15, 15): g=36
# Expandiendo (15, 16): g=37
# Expandiendo (15, 17): g=38
# Expandiendo (16, 17): g=39
# Expandiendo (17, 17): g=40
# Expandiendo (1, 1): g=0
# Expandiendo (1, 2): g=1
# Expandiendo (1, 3): g=2
# Expandiendo (2, 3): g=3
# Expandiendo (3, 3): g=4
# Expandiendo (4, 3): g=5
# Expandiendo (3, 4): g=5
# Expandiendo (5, 3): g=6
# Expandiendo (3, 5): g=6
# Expandiendo (3, 6): g=7
# Expandiendo (3, 7): g=8
# Expandiendo (4, 7): g=9
# Expandiendo (5, 7): g=10
# Expandiendo (5, 2): g=7
# Expandiendo (2, 5): g=7
# Expandiendo (2, 7): g=9
# Expandiendo (5, 6): g=11
# Expandiendo (5, 1): g=8
# Expandiendo (1, 5): g=8
# Expandiendo (1, 7): g=10
# Expandiendo (5, 5): g=12
# Expandiendo (6, 1): g=9
# Expandiendo (1, 6): g=9
# Expandiendo (1, 8): g=11
# Expandiendo (6, 5): g=13
# Expandiendo (7, 1): g=10
# Expandiendo (1, 9): g=12
# Expandiendo (7, 5): g=14
# Expandiendo (7, 2): g=11
# Expandiendo (1, 10): g=13
# Expandiendo (8, 5): g=15
# Expandiendo (7, 3): g=12
# Expandiendo (1, 11): g=14
# Expandiendo (9, 5): g=16
# Expandiendo (8, 3): g=13
# Expandiendo (2, 11): g=15
# Expandiendo (1, 12): g=15
# Expandiendo (10, 5): g=17
# Expandiendo (9, 3): g=14
# Expandiendo (3, 11): g=16
# Expandiendo (1, 13): g=16
# Expandiendo (11, 5): g=18
# Expandiendo (10, 3): g=15
# Expandiendo (4, 11): g=17
# Expandiendo (2, 13): g=17
# Expandiendo (1, 14): g=17
# Expandiendo (12, 5): g=19
# Expandiendo (11, 6): g=19
# Expandiendo (11, 3): g=16
# Expandiendo (5, 11): g=18
# Expandiendo (3, 13): g=18
# Expandiendo (1, 15): g=18
# Expandiendo (13, 5): g=20
# Expandiendo (11, 7): g=20
# Expandiendo (11, 4): g=17
# Expandiendo (6, 11): g=19
# Expandiendo (5, 12): g=19
# Expandiendo (4, 13): g=19
# Expandiendo (2, 15): g=19
# Expandiendo (1, 16): g=19
# Expandiendo (14, 5): g=21
# Expandiendo (12, 7): g=21
# Expandiendo (11, 8): g=21
# Expandiendo (7, 11): g=20
# ...
# Frontier después de expandir: [(11, 13), (1, 11), (3, 13), (5, 11), (5, 15), (9, 15), (7, 17), (14, 9), (15, 10)]
# ---------------------------------------------
# Expandiendo: (11, 13)
# Frontier después de expandir: [(1, 11), (3, 13), (5, 11), (5, 15), (9, 15), (7, 17), (14, 9), (15, 10), (12, 13)]
# ---------------------------------------------
# Expandiendo: (1, 11)
# Frontier después de expandir: [(3, 13), (5, 11), (5, 15), (9, 15), (7, 17), (14, 9), (15, 10), (12, 13), (1, 12)]
# ---------------------------------------------
# Expandiendo: (3, 13)
# Frontier después de expandir: [(5, 11), (5, 15), (9, 15), (7, 17), (14, 9), (15, 10), (12, 13), (1, 12), (2, 13), (3, 14)]
# ---------------------------------------------
# Expandiendo: (5, 11)
# Frontier después de expandir: [(5, 15), (9, 15), (7, 17), (14, 9), (15, 10), (12, 13), (1, 12), (2, 13), (3, 14), (4, 11)]
# ---------------------------------------------
# Expandiendo: (5, 15)
# Frontier después de expandir: [(9, 15), (7, 17), (14, 9), (15, 10), (12, 13), (1, 12), (2, 13), (3, 14), (4, 11)]
# ---------------------------------------------
# Expandiendo: (9, 15)
# Frontier después de expandir: [(7, 17), (14, 9), (15, 10), (12, 13), (1, 12), (2, 13), (3, 14), (4, 11), (9, 16)]
# ---------------------------------------------
# Expandiendo: (7, 17)
# Frontier después de expandir: [(14, 9), (15, 10), (12, 13), (1, 12), (2, 13), (3, 14), (4, 11), (9, 16), (6, 17), (8, 17), (7, 18)]
# ---------------------------------------------
# Expandiendo: (14, 9)
# Frontier después de expandir: [(15, 10), (12, 13), (1, 12), (2, 13), (3, 14), (4, 11), (9, 16), (6, 17), (8, 17), (7, 18), (13, 9)]
# ---------------------------------------------
# Expandiendo: (15, 10)
# Frontier después de expandir: [(12, 13), (1, 12), (2, 13), (3, 14), (4, 11), (9, 16), (6, 17), (8, 17), (7, 18), (13, 9), (15, 11)]
# ---------------------------------------------
# Expandiendo: (12, 13)
# Frontier después de expandir: [(1, 12), (2, 13), (3, 14), (4, 11), (9, 16), (6, 17), (8, 17), (7, 18), (13, 9), (15, 11), (13, 13)]
# ---------------------------------------------
# Expandiendo: (1, 12)
# Frontier después de expandir: [(2, 13), (3, 14), (4, 11), (9, 16), (6, 17), (8, 17), (7, 18), (13, 9), (15, 11), (13, 13), (1, 13)]
# ---------------------------------------------
# Expandiendo: (2, 13)
# Frontier después de expandir: [(3, 14), (4, 11), (9, 16), (6, 17), (8, 17), (7, 18), (13, 9), (15, 11), (13, 13), (1, 13)]
# ---------------------------------------------
# Expandiendo: (3, 14)
# Frontier después de expandir: [(4, 11), (9, 16), (6, 17), (8, 17), (7, 18), (13, 9), (15, 11), (13, 13), (1, 13), (3, 15)]
# ---------------------------------------------
# Expandiendo: (4, 11)
# Frontier después de expandir: [(9, 16), (6, 17), (8, 17), (7, 18), (13, 9), (15, 11), (13, 13), (1, 13), (3, 15), (3, 11)]
# ---------------------------------------------
# Expandiendo: (9, 16)
# Frontier después de expandir: [(6, 17), (8, 17), (7, 18), (13, 9), (15, 11), (13, 13), (1, 13), (3, 15), (3, 11), (9, 17)]
# ---------------------------------------------
# Expandiendo: (6, 17)
# Frontier después de expandir: [(8, 17), (7, 18), (13, 9), (15, 11), (13, 13), (1, 13), (3, 15), (3, 11), (9, 17), (5, 17)]
# ---------------------------------------------
# Expandiendo: (8, 17)
# Frontier después de expandir: [(7, 18), (13, 9), (15, 11), (13, 13), (1, 13), (3, 15), (3, 11), (9, 17), (5, 17)]
# ---------------------------------------------
# Expandiendo: (7, 18)
# Frontier después de expandir: [(13, 9), (15, 11), (13, 13), (1, 13), (3, 15), (3, 11), (9, 17), (5, 17), (7, 19)]
# ---------------------------------------------
# Expandiendo: (13, 9)
# Frontier después de expandir: [(15, 11), (13, 13), (1, 13), (3, 15), (3, 11), (9, 17), (5, 17), (7, 19), (13, 10)]
# ---------------------------------------------
# Expandiendo: (15, 11)
# Frontier después de expandir: [(13, 13), (1, 13), (3, 15), (3, 11), (9, 17), (5, 17), (7, 19), (13, 10), (14, 11), (15, 12)]
# ---------------------------------------------
# Expandiendo: (13, 13)
# Frontier después de expandir: [(1, 13), (3, 15), (3, 11), (9, 17), (5, 17), (7, 19), (13, 10), (14, 11), (15, 12), (13, 12)]
# ---------------------------------------------
# Expandiendo: (1, 13)
# Frontier después de expandir: [(3, 15), (3, 11), (9, 17), (5, 17), (7, 19), (13, 10), (14, 11), (15, 12), (13, 12)]
# ---------------------------------------------
# Expandiendo: (3, 15)
# Frontier después de expandir: [(3, 11), (9, 17), (5, 17), (7, 19), (13, 10), (14, 11), (15, 12), (13, 12), (2, 15), (3, 16)]
# ---------------------------------------------
# Expandiendo: (3, 11)
# Frontier después de expandir: [(9, 17), (5, 17), (7, 19), (13, 10), (14, 11), (15, 12), (13, 12), (2, 15), (3, 16)]
# ---------------------------------------------
# Expandiendo: (9, 17)
# Frontier después de expandir: [(5, 17), (7, 19), (13, 10), (14, 11), (15, 12), (13, 12), (2, 15), (3, 16)]
# ---------------------------------------------
# Expandiendo: (5, 17)
# Frontier después de expandir: [(7, 19), (13, 10), (14, 11), (15, 12), (13, 12), (2, 15), (3, 16), (5, 18)]
# ---------------------------------------------
# Expandiendo: (7, 19)
# Frontier después de expandir: [(13, 10), (14, 11), (15, 12), (13, 12), (2, 15), (3, 16), (5, 18), (8, 19)]
# ---------------------------------------------
# Expandiendo: (13, 10)
# Frontier después de expandir: [(14, 11), (15, 12), (13, 12), (2, 15), (3, 16), (5, 18), (8, 19), (13, 11)]
# ---------------------------------------------
# Expandiendo: (14, 11)
# Frontier después de expandir: [(15, 12), (13, 12), (2, 15), (3, 16), (5, 18), (8, 19), (13, 11)]
# ---------------------------------------------
# Expandiendo: (15, 12)
# Frontier después de expandir: [(13, 12), (2, 15), (3, 16), (5, 18), (8, 19), (13, 11), (15, 13)]
# ---------------------------------------------
# Expandiendo: (13, 12)
# Frontier después de expandir: [(2, 15), (3, 16), (5, 18), (8, 19), (13, 11), (15, 13)]
# ---------------------------------------------
# Expandiendo: (2, 15)
# Frontier después de expandir: [(3, 16), (5, 18), (8, 19), (13, 11), (15, 13), (1, 15)]
# ---------------------------------------------
# Expandiendo: (3, 16)
# Frontier después de expandir: [(5, 18), (8, 19), (13, 11), (15, 13), (1, 15), (3, 17)]
# ---------------------------------------------
# Expandiendo: (5, 18)
# Frontier después de expandir: [(8, 19), (13, 11), (15, 13), (1, 15), (3, 17), (5, 19)]
# ---------------------------------------------
# Expandiendo: (8, 19)
# Frontier después de expandir: [(13, 11), (15, 13), (1, 15), (3, 17), (5, 19), (9, 19)]
# ---------------------------------------------
# Expandiendo: (13, 11)
# Frontier después de expandir: [(15, 13), (1, 15), (3, 17), (5, 19), (9, 19)]
# ---------------------------------------------
# Expandiendo: (15, 13)
# Frontier después de expandir: [(1, 15), (3, 17), (5, 19), (9, 19), (15, 14)]
# ---------------------------------------------
# Expandiendo: (1, 15)
# Frontier después de expandir: [(3, 17), (5, 19), (9, 19), (15, 14), (1, 16)]
# ---------------------------------------------
# Expandiendo: (3, 17)
# Frontier después de expandir: [(5, 19), (9, 19), (15, 14), (1, 16)]
# ---------------------------------------------
# Expandiendo: (5, 19)
# Frontier después de expandir: [(9, 19), (15, 14), (1, 16), (4, 19)]
# ---------------------------------------------
# Expandiendo: (9, 19)
# Frontier después de expandir: [(15, 14), (1, 16), (4, 19), (10, 19)]
# ---------------------------------------------
# Expandiendo: (15, 14)
# Frontier después de expandir: [(1, 16), (4, 19), (10, 19), (15, 15)]
# ---------------------------------------------
# Expandiendo: (1, 16)
# Frontier después de expandir: [(4, 19), (10, 19), (15, 15), (1, 17)]
# ---------------------------------------------
# Expandiendo: (4, 19)
# Frontier después de expandir: [(10, 19), (15, 15), (1, 17), (3, 19)]
# ---------------------------------------------
# Expandiendo: (10, 19)
# Frontier después de expandir: [(15, 15), (1, 17), (3, 19), (11, 19)]
# ---------------------------------------------
# Expandiendo: (15, 15)
# Frontier después de expandir: [(1, 17), (3, 19), (11, 19), (14, 15)]
# ---------------------------------------------
# Expandiendo: (1, 17)
# Frontier después de expandir: [(3, 19), (11, 19), (14, 15), (1, 18)]
# ---------------------------------------------
# Expandiendo: (3, 19)
# Frontier después de expandir: [(11, 19), (14, 15), (1, 18), (2, 19)]
# ---------------------------------------------
# Expandiendo: (11, 19)
# Frontier después de expandir: [(14, 15), (1, 18), (2, 19), (12, 19), (11, 18)]
# ---------------------------------------------
# Expandiendo: (14, 15)
# Frontier después de expandir: [(1, 18), (2, 19), (12, 19), (11, 18), (13, 15)]
# ---------------------------------------------
# Expandiendo: (1, 18)
# Frontier después de expandir: [(2, 19), (12, 19), (11, 18), (13, 15), (1, 19)]
# ---------------------------------------------
# Expandiendo: (2, 19)
# Frontier después de expandir: [(12, 19), (11, 18), (13, 15), (1, 19)]
# ---------------------------------------------
# Expandiendo: (12, 19)
# Frontier después de expandir: [(11, 18), (13, 15), (1, 19), (13, 19)]
# ---------------------------------------------
# Expandiendo: (11, 18)
# Frontier después de expandir: [(13, 15), (1, 19), (13, 19), (11, 17)]
# ---------------------------------------------
# Expandiendo: (13, 15)
# Frontier después de expandir: [(1, 19), (13, 19), (11, 17), (12, 15)]
# ---------------------------------------------
# Expandiendo: (1, 19)
# Frontier después de expandir: [(13, 19), (11, 17), (12, 15)]
# ---------------------------------------------
# Expandiendo: (13, 19)
# Frontier después de expandir: [(11, 17), (12, 15), (14, 19)]
# ---------------------------------------------
# Expandiendo: (11, 17)
# Frontier después de expandir: [(12, 15), (14, 19), (11, 16)]
# ---------------------------------------------
# Expandiendo: (12, 15)
# Frontier después de expandir: [(14, 19), (11, 16), (11, 15)]
# ---------------------------------------------
# Expandiendo: (14, 19)
# Frontier después de expandir: [(11, 16), (11, 15), (15, 19)]
# ---------------------------------------------
# Expandiendo: (11, 16)
# Frontier después de expandir: [(11, 15), (15, 19)]
# ---------------------------------------------
# Expandiendo: (11, 15)
# Frontier después de expandir: [(15, 19)]
# ---------------------------------------------
# Expandiendo: (15, 19)
# Expandiendo (1, 1): g=0
# Expandiendo (2, 1): g=1
# Expandiendo (3, 1): g=2
# Expandiendo (4, 1): g=3
# Expandiendo (5, 1): g=4
# Expandiendo (6, 1): g=5
# Expandiendo (7, 1): g=6
# Expandiendo (8, 1): g=7
# Expandiendo (9, 1): g=8
# Expandiendo (9, 2): g=9
# Expandiendo (9, 3): g=10
# Expandiendo (10, 3): g=11
# Expandiendo (11, 3): g=12
# Expandiendo (12, 3): g=13
# Expandiendo (13, 3): g=14
# Expandiendo (13, 4): g=15
# Expandiendo (13, 5): g=16
# Expandiendo (14, 5): g=17
# Expandiendo (15, 5): g=18
# Expandiendo (13, 6): g=17
# Expandiendo (13, 7): g=18
# Expandiendo (14, 7): g=19
# Expandiendo (15, 7): g=20
# Expandiendo (15, 8): g=21
# Expandiendo (15, 9): g=22
# Expandiendo (15, 10): g=23
# Expandiendo (15, 11): g=24
# Expandiendo (15, 12): g=25
# Expandiendo (15, 13): g=26
# Expandiendo (15, 14): g=27
# Expandiendo (15, 15): g=28
# Expandiendo (14, 15): g=29
# Expandiendo (13, 15): g=30
# Expandiendo (12, 15): g=31
# Expandiendo (11, 15): g=32
# Expandiendo (11, 16): g=33
# Expandiendo (11, 17): g=34
# Expandiendo (11, 18): g=35
# Expandiendo (11, 19): g=36
# Expandiendo (12, 19): g=37
# Expandiendo (13, 19): g=38
# Expandiendo (14, 19): g=39
# Expandiendo (15, 19): g=40
# Expandiendo (1, 1): g=0
# Expandiendo (2, 1): g=1
# Expandiendo (1, 2): g=1
# Expandiendo (3, 1): g=2
# Expandiendo (1, 3): g=2
# Expandiendo (4, 1): g=3
# Expandiendo (2, 3): g=3
# Expandiendo (5, 1): g=4
# Expandiendo (3, 3): g=4
# Expandiendo (6, 1): g=5
# Expandiendo (4, 3): g=5
# Expandiendo (7, 1): g=6
# Expandiendo (5, 3): g=6
# Expandiendo (8, 1): g=7
# Expandiendo (7, 2): g=7
# Expandiendo (5, 4): g=7
# Expandiendo (9, 1): g=8
# Expandiendo (7, 3): g=8
# Expandiendo (5, 5): g=8
# Expandiendo (9, 2): g=9
# Expandiendo (7, 4): g=9
# Expandiendo (6, 5): g=9
# Expandiendo (5, 6): g=9
# Expandiendo (9, 3): g=10
# Expandiendo (7, 5): g=10
# Expandiendo (5, 7): g=10
# Expandiendo (10, 3): g=11
# Expandiendo (9, 4): g=11
# Expandiendo (7, 6): g=11
# Expandiendo (6, 7): g=11
# Expandiendo (11, 3): g=12
# Expandiendo (9, 5): g=12
# Expandiendo (7, 7): g=12
# Expandiendo (12, 3): g=13
# Expandiendo (10, 5): g=13
# Expandiendo (8, 7): g=13
# Expandiendo (7, 8): g=13
# Expandiendo (13, 3): g=14
# Expandiendo (11, 5): g=14
# Expandiendo (9, 7): g=14
# Expandiendo (7, 9): g=14
# Expandiendo (13, 4): g=15
# Expandiendo (12, 5): g=15
# Expandiendo (11, 6): g=15
# Expandiendo (8, 9): g=15
# Expandiendo (7, 10): g=15
# Expandiendo (13, 5): g=16
# Expandiendo (11, 7): g=16
# Expandiendo (9, 9): g=16
# Expandiendo (7, 11): g=16
# Expandiendo (14, 5): g=17
# Expandiendo (13, 6): g=17
# Expandiendo (12, 7): g=17
# Expandiendo (11, 8): g=17
# Expandiendo (10, 9): g=17
# Expandiendo (9, 10): g=17
# Expandiendo (7, 12): g=17
# Expandiendo (15, 5): g=18
# Expandiendo (13, 7): g=18
# Expandiendo (11, 9): g=18
# Expandiendo (9, 11): g=18
# Expandiendo (7, 13): g=18
# Expandiendo (14, 7): g=19
# Expandiendo (11, 10): g=19
# Expandiendo (10, 11): g=19
# Expandiendo (8, 13): g=19
# Expandiendo (7, 14): g=19
# Expandiendo (15, 7): g=20
# Expandiendo (11, 11): g=20
# Expandiendo (9, 13): g=20
# Expandiendo (7, 15): g=20
# Expandiendo (15, 8): g=21
# Expandiendo (11, 12): g=21
# Expandiendo (10, 13): g=21
# Expandiendo (9, 14): g=21
# Expandiendo (8, 15): g=21
# Expandiendo (7, 16): g=21
# Expandiendo (15, 9): g=22
# Expandiendo (11, 13): g=22
# Expandiendo (9, 15): g=22
# Expandiendo (7, 17): g=22
# Expandiendo (15, 10): g=23
# Expandiendo (12, 13): g=23
# Expandiendo (9, 16): g=23
# Expandiendo (8, 17): g=23
# Expandiendo (7, 18): g=23
# Expandiendo (15, 11): g=24
# Expandiendo (13, 13): g=24
# Expandiendo (9, 17): g=24
# Expandiendo (7, 19): g=24
# Expandiendo (15, 12): g=25
# Expandiendo (8, 19): g=25
# Expandiendo (15, 13): g=26
# Expandiendo (9, 19): g=26
# Expandiendo (15, 14): g=27
# Expandiendo (10, 19): g=27
# Expandiendo (15, 15): g=28
# Expandiendo (11, 19): g=28
# Expandiendo (12, 19): g=29
# Expandiendo (13, 19): g=30
# Expandiendo (14, 19): g=31
# Expandiendo (15, 19): g=32
# [{'algoritmo': 'DFS',
#   'estados_explorados': 69,
#   'longitud_camino': 64,
#   'costo_camino': 64,
#   'laberinto': 'mazes/mazes/maze1.txt'},
#  {'algoritmo': 'BFS',
#   'estados_explorados': 106,
#   'longitud_camino': 28,
#   'costo_camino': 28,
#   'laberinto': 'mazes/mazes/maze1.txt'},
#  {'algoritmo': 'UCS',
#   'estados_explorados': 106,
#   'longitud_camino': 28,
#   'costo_camino': 28,
#   'laberinto': 'mazes/mazes/maze1.txt'},
#  {'algoritmo': 'Greedy',
#   'estados_explorados': 33,
#   'longitud_camino': 32,
#   'costo_camino': 32,
#   'laberinto': 'mazes/mazes/maze1.txt'},
#  {'algoritmo': 'A*',
#   'estados_explorados': 59,
#   'longitud_camino': 28,
#   'costo_camino': 28,
#   'laberinto': 'mazes/mazes/maze1.txt'},
#  {'algoritmo': 'DFS',
#   'estados_explorados': 41,
#   'longitud_camino': 40,
#   'costo_camino': 40,
#   'laberinto': 'mazes/mazes/maze2.txt'},
#  {'algoritmo': 'BFS',
#   'estados_explorados': 176,
#   'longitud_camino': 36,
#   'costo_camino': 36,
#   'laberinto': 'mazes/mazes/maze2.txt'},
#  {'algoritmo': 'UCS',
#   'estados_explorados': 176,
#   'longitud_camino': 36,
#   'costo_camino': 36,
#   'laberinto': 'mazes/mazes/maze2.txt'},
#  {'algoritmo': 'Greedy',
#   'estados_explorados': 51,
#   'longitud_camino': 40,
#   'costo_camino': 40,
#   'laberinto': 'mazes/mazes/maze2.txt'},
#  {'algoritmo': 'A*',
#   'estados_explorados': 141,
#   'longitud_camino': 36,
#   'costo_camino': 36,
#   'laberinto': 'mazes/mazes/maze2.txt'},
#  {'algoritmo': 'DFS',
#   'estados_explorados': 115,
#   'longitud_camino': 32,
#   'costo_camino': 32,
#   'laberinto': 'mazes/mazes/maze3.txt'},
#  {'algoritmo': 'BFS',
#   'estados_explorados': 172,
#   'longitud_camino': 32,
#   'costo_camino': 32,
#   'laberinto': 'mazes/mazes/maze3.txt'},
#  {'algoritmo': 'UCS',
#   'estados_explorados': 172,
#   'longitud_camino': 32,
#   'costo_camino': 32,
#   'laberinto': 'mazes/mazes/maze3.txt'},
#  {'algoritmo': 'Greedy',
#   'estados_explorados': 43,
#   'longitud_camino': 40,
#   'costo_camino': 40,
#   'laberinto': 'mazes/mazes/maze3.txt'},
#  {'algoritmo': 'A*',
#   'estados_explorados': 102,
#   'longitud_camino': 32,
#   'costo_camino': 32,
#   'laberinto': 'mazes/mazes/maze3.txt'}]

# %%
for filename in ["mazes/mazes/maze1.txt", "mazes/mazes/maze2.txt", "mazes/mazes/maze3.txt"]:
    rows = [row for row in all_summaries if row["laberinto"] == filename]
    labels = [row["algoritmo"] for row in rows]
    values = [row["estados_explorados"] for row in rows]

    plt.figure(figsize=(8, 4))
    plt.bar(labels, values)
    plt.ylabel("Estados explorados")
    plt.title(f"Comparación de algoritmos — {filename}")
    plt.show()

# %% [markdown]
# ### Propiedades teóricas
#
# | Algoritmo | Estrategia | Completo | Óptimo |
# |---|---|---:|---:|
# | DFS | Nodo más profundo | No, en espacios infinitos | No |
# | BFS | Nodo menos profundo | Sí, con ramificación finita | Sí, con costos iguales |
# | UCS | Menor \(g(n)\) | Sí, con costos positivos | Sí |
# | Greedy | Menor \(h(n)\) | No siempre | No |
# | A* | Menor \(g(n)+h(n)\) | Sí, bajo condiciones estándar | Sí, con heurística admisible |
#
# La eficiencia observada depende de la estructura de cada laberinto y del orden en que `neighbors()` genera las direcciones.

# %% [markdown]
# ## Reto de implementación (extensión conceptual, no evaluada)
#
# Elige **una** de estas variantes y formalízala como problema de búsqueda antes de tocar código:
#
# - movimientos diagonales;
# - llaves y puertas;
# - múltiples metas;
# - celdas con costos distintos por dirección de entrada;
# - un enemigo que cambia de posición en cada paso del agente.
#
# Para la variante elegida, especifica por escrito:
#
# 1. **Estado:** ¿qué información mínima necesitas para que el estado determine completamente el comportamiento futuro? (Pista: si eliges "enemigo que se mueve", la posición del agente sola ya no basta — el estado también debe incluir la posición del enemigo.)
# 2. **Acciones** disponibles en cada estado.
# 3. **Modelo de transición.**
# 4. **Costo de cada acción.**
# 5. **Heurística propuesta** y si es admisible: da un argumento, no solo una intuición.

# %% [markdown]
# ## Cierre
#
# Las búsquedas no informadas (DFS, BFS, UCS) utilizan únicamente la estructura del problema. Las búsquedas informadas (Greedy, A*) incorporan conocimiento adicional mediante una heurística.
#
# Lo que debería quedar claro después de este notebook:
#
# - **El algoritmo no cambió entre el grafo y el laberinto.** Cambió la representación del problema (`graph[state]` → `maze.neighbors(state)`) y cómo se calcula la heurística (tabla fija → función de la coordenada).
# - **Greedy y A* ponderado comparten el mismo defecto:** ignoran (total o parcialmente) el costo ya acumulado, y por eso pueden caer en rutas subóptimas cuando la heurística "promete" de más.
# - **UCS y A* con heurística admisible son los únicos con garantía de optimalidad** cuando los costos no son uniformes.
#
# La elección del algoritmo en un problema real depende de: si necesitamos una solución óptima, si los costos son uniformes, cuánta memoria tenemos, qué tan buena es la heurística, y qué tan grande es el espacio de estados.
